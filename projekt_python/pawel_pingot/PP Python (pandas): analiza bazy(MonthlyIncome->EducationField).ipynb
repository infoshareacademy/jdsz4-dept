# %%
import pandas as pd

# %%
data_frame = pd.read_csv("/home/pawcio/Desktop/Projekty/tabele_zawody/WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
total_base = (data_frame[['MonthlyIncome', 'EducationField', 'Education', 'TotalWorkingYears', 'Department', 'JobRole']])
print(total_base)
# Out:
#       MonthlyIncome EducationField  Education  TotalWorkingYears  \
# 0              5993  Life Sciences          2                  8
# 1              5130  Life Sciences          1                 10
# 2              2090          Other          2                  7
# 3              2909  Life Sciences          4                  8
# 4              3468        Medical          1                  6
# ...             ...            ...        ...                ...
# 1465           2571        Medical          2                 17
# 1466           9991        Medical          1                  9
# 1467           6142  Life Sciences          3                  6
# 1468           5390        Medical          3                 17
# 1469           4404        Medical          3                  6
#
#                   Department                    JobRole
# 0                      Sales            Sales Executive
# 1     Research & Development         Research Scientist
# 2     Research & Development      Laboratory Technician
# 3     Research & Development         Research Scientist
# 4     Research & Development      Laboratory Technician
# ...                      ...                        ...
# 1465  Research & Development      Laboratory Technician
# 1466  Research & Development  Healthcare Representative
# 1467  Research & Development     Manufacturing Director
# 1468                   Sales            Sales Executive
# 1469  Research & Development      Laboratory Technician
#
# [1470 rows x 6 columns]

# %%
lista_Monthlyincome = list(total_base['MonthlyIncome'])
lista_EducationField = list(total_base['EducationField'])
lista_Education = list(total_base['Education'])
lista_Department = list(total_base['Department'])
lista_TotalWorkingYears = list(total_base['TotalWorkingYears'])
lista_JobRole = list(total_base['JobRole'])

# %%
total_list = sorted(list(zip(lista_Monthlyincome, lista_EducationField, lista_Education, lista_Department, lista_TotalWorkingYears, lista_JobRole)))

# %%
def educationfield(lista, educationfield):
    all_found = []
    for element in total_list:
        if element[1] == str(educationfield):
            add_to_all_found = True
            for element2 in all_found:
                for key, value in element2.items():
                    klucz = key
                    wartosc = value
                if klucz == element[3] and wartosc == element[5]:
                    add_to_all_found = False
                    break
            if add_to_all_found:
                 all_found.append({element[3]: element[5]}) 
    return all_found
print(total_list, 'Medical')
# Out:
# [(1009, 'Medical', 1, 'Research & Development', 1, 'Research Scientist'), (1051, 'Life Sciences', 2, 'Research & Development', 0, 'Research Scientist'), (1052, 'Medical', 1, 'Sales', 1, 'Sales Representative'), (1081, 'Medical', 3, 'Sales', 1, 'Sales Representative'), (1091, 'Technical Degree', 3, 'Sales', 1, 'Sales Representative'), (1102, 'Life Sciences', 3, 'Research & Development', 1, 'Laboratory Technician'), (1118, 'Life Sciences', 1, 'Sales', 1, 'Sales Representative'), (1129, 'Medical', 1, 'Research & Development', 1, 'Laboratory Technician'), (1200, 'Medical', 3, 'Sales', 0, 'Sales Representative'), (1223, 'Life Sciences', 2, 'Research & Development', 1, 'Research Scientist'), (1232, 'Life Sciences', 2, 'Research & Development', 0, 'Research Scientist'), (1261, 'Life Sciences', 3, 'Research & Development', 1, 'Research Scientist'), (1274, 'Technical Degree', 3, 'Research & Development', 1, 'Research Scientist'), (1281, 'Life Sciences', 3, 'Research & Development', 1, 'Laboratory Technician'), (1359, 'Life Sciences', 4, 'Sales', 1, 'Sales Representative'), (1393, 'Life Sciences', 4, 'Research & Development', 1, 'Laboratory Technician'), (1416, 'Life Sciences', 3, 'Research & Development', 1, 'Laboratory Technician'), (1420, 'Life Sciences', 3, 'Research & Development', 0, 'Laboratory Technician'), (1483, 'Medical', 1, 'Research & Development', 1, 'Laboratory Technician'), (1514, 'Medical', 3, 'Research & Development', 0, 'Research Scientist'), (1555, 'Human Resources', 1, 'Human Resources', 1, 'Human Resources'), (1563, 'Life Sciences', 3, 'Research & Development', 1, 'Research Scientist'), (1569, 'Medical', 2, 'Sales', 0, 'Sales Representative'), (1601, 'Life Sciences', 3, 'Research & Development', 1, 'Laboratory Technician'), (1611, 'Life Sciences', 3, 'Research & Development', 0, 'Laboratory Technician'), (1675, 'Marketing', 1, 'Sales', 0, 'Sales Representative'), (1702, 'Life Sciences', 2, 'Research & Development', 1, 'Laboratory Technician'), (1706, 'Medical', 3, 'Research & Development', 0, 'Research Scientist'), (1790, 'Marketing', 3, 'Sales', 1, 'Sales Representative'), (1859, 'Medical', 3, 'Research & Development', 1, 'Research Scientist'), (1878, 'Marketing', 3, 'Sales', 0, 'Sales Representative'), (1904, 'Medical', 1, 'Research & Development', 0, 'Laboratory Technician'), (1951, 'Other', 2, 'Research & Development', 1, 'Laboratory Technician'), (2001, 'Medical', 4, 'Research & Development', 20, 'Research Scientist'), (2007, 'Medical', 1, 'Research & Development', 5, 'Research Scientist'), (2008, 'Life Sciences', 3, 'Research & Development', 1, 'Laboratory Technician'), (2008, 'Medical', 2, 'Research & Development', 1, 'Laboratory Technician'), (2011, 'Life Sciences', 1, 'Research & Development', 10, 'Research Scientist'), (2013, 'Life Sciences', 3, 'Research & Development', 15, 'Laboratory Technician'), (2014, 'Marketing', 3, 'Sales', 2, 'Sales Representative'), (2018, 'Life Sciences', 4, 'Research & Development', 15, 'Laboratory Technician'), (2022, 'Life Sciences', 4, 'Research & Development', 10, 'Research Scientist'), (2024, 'Medical', 3, 'Research & Development', 6, 'Research Scientist'), (2028, 'Life Sciences', 3, 'Research & Development', 6, 'Laboratory Technician'), (2028, 'Medical', 3, 'Research & Development', 14, 'Laboratory Technician'), (2029, 'Technical Degree', 1, 'Research & Development', 5, 'Research Scientist'), (2033, 'Life Sciences', 2, 'Sales', 1, 'Sales Representative'), (2033, 'Life Sciences', 4, 'Sales', 1, 'Sales Representative'), (2042, 'Life Sciences', 3, 'Research & Development', 6, 'Research Scientist'), (2042, 'Medical', 3, 'Research & Development', 17, 'Laboratory Technician'), (2044, 'Life Sciences', 3, 'Research & Development', 5, 'Research Scientist'), (2044, 'Medical', 3, 'Sales', 2, 'Sales Representative'), (2045, 'Medical', 4, 'Research & Development', 5, 'Research Scientist'), (2058, 'Technical Degree', 3, 'Research & Development', 7, 'Research Scientist'), (2061, 'Life  ...

# %%
def total_working_years(lista, totalworkingyears):
    all_found = []
    for element in total_list:
        if element[4] == int(totalworkingyears):
            add_to_all_found = True
            for element2 in all_found:
                for key, value in element2.items():
                    klucz = key
                    wartosc = value
                if klucz == element[3] and wartosc == element[5]:
                    add_to_all_found = False
                    break
            if add_to_all_found:
                 all_found.append({element[3]: element[5]}) 
    return all_found

# %%
def edu_monthly(data, user_value):
    all_found_test = []
    for element in data:
        if element[2] == user_value:
            add_to_all_found_test = True
            for element2 in all_found_test:
                for key, value in element2.items():
                    klucz = key
                    wartosc = value
                if klucz == element[3] and wartosc == element[5] :
                    add_to_all_found_test = False
                    break
            if add_to_all_found_test:
                all_found_test.append({element[3]: element[5]})
    return all_found_test

# %%
def depart_job_range(data, min_value, max_value):
    all_found = []
    for element in data:
        if str(max_value) == 'no max':
            max_value = 2147483647
        if element[0] >= int(min_value) and element[0] < int(max_value):
            add_to_all_found = True
            for element2 in all_found:
                for key, value in element2.items():
                    klucz = key
                    wartosc = value
                if klucz == element[3] and wartosc == element[5]:
                    add_to_all_found = False
                    break
            if add_to_all_found:
                #print(str(element[1]) + ' ' + element[2])
                #printed.update({element[1]: element[2]})
                all_found.append({element[3]: element[5]}) 
    return all_found

# %%
value = int(input('Jakie są Twoje wymarzone zarobki?:'))

print('Oto propozycje stanowisk dla Ciebie:')
if value >= 11001:
    wyniki = depart_job_range(total_list, 11000, "no max")
    for wynik in wyniki:
        for key, value in wynik.items():
            print('Departament: ' + str(key) + '   Stanowisko: ' + str(value))
elif value >=9001 and value <= 11000:
    wyniki = depart_job_range(total_list, 9000, 11000)
    for wynik in wyniki:
        for key, value in wynik.items():
            print('Departament: ' + str(key) + '   Stanowisko: ' + str(value))  
elif value >= 5001 and value <= 9000:
    wyniki = depart_job_range(total_list, 5000, 9000)
    for wynik in wyniki:
        for key, value in wynik.items():
            print('Departament: ' + str(key) + '   Stanowisko: ' + str(value))
elif value >= 3001 and value <= 5000:
    wyniki = depart_job_range(total_list, 3000, 5000)
    for wynik in wyniki:
        for key, value in wynik.items():
            print('Departament: ' + str(key) + '   Stanowisko: ' + str(value))
elif value <= 3000:
    wyniki = depart_job_range(total_list, 0, 3000)
    for wynik in wyniki:
        for key, value in wynik.items():
            print('Departament: ' + str(key) + '   Stanowisko: ' + str(value)) 
else:
    print('nic')
# Out:
# Jakie są Twoje wymarzone zarobki?:15000
# Oto propozycje stanowisk dla Ciebie:
# Departament: Research & Development   Stanowisko: Research Director
# Departament: Research & Development   Stanowisko: Healthcare Representative
# Departament: Research & Development   Stanowisko: Manager
# Departament: Sales   Stanowisko: Manager
# Departament: Sales   Stanowisko: Sales Executive
# Departament: Research & Development   Stanowisko: Manufacturing Director
# Departament: Human Resources   Stanowisko: Manager

# %%
def depart_job_rangee(data, min_value, max_value, totalworkingyears, educationfield, education):
    all_found = []
    for element in data:
        if str(max_value) == 'no max':
            max_value = 2147483647
        if element[0] >= int(min_value) and element[0] < int(max_value) and element[4] == int(totalworkingyears) and element[1] == str(educationfield) and element[2] == int(education):
            add_to_all_found = True
            for element2 in all_found:
                for key, value in element2.items():
                    klucz = key
                    wartosc = value
                if klucz == element[3] and wartosc == element[5]:
                    add_to_all_found = False
                    break
            if add_to_all_found:
                #print(str(element[1]) + ' ' + element[2])
                #printed.update({element[1]: element[2]})
                all_found.append({element[3]: element[5]}) 
    return all_found
print(depart_job_rangee(total_list,10000, 12000, 10,'Other','4'))
# Out:
# []

# %%
df_first_filtred = total_base[(total_base["MonthlyIncome"] >= 5000) & (total_base["MonthlyIncome"] <= 9000)]
print(mi_filtred_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b298267bc512> in <module>
#       1 df_first_filtred = total_base[(total_base["MonthlyIncome"] >= 5000) & (total_base["MonthlyIncome"] <= 9000)]
# ----> 2 print(mi_filtred_df)
#
# NameError: name 'mi_filtred_df' is not defined

# %%
user_monthlyIncome = int(input('Jakie są Twoje wymarzone zarobki?:'))
user_totalworkingyears = int(input())
user_educationfield = str(input())
user_education = int(input())
def get_income_limits(user_monthlyIncome):
    limits = [
        (1000, 3000),
        (3000, 5000),
        (5000, 7000),
        (7000, 9000),
        (9000, 11000),
        (11000, 13000),
        (13000, 15000),
        (15000, 17000),
        (17000,20000)
    ]
    for min_val, max_val in limits:
        if min_val < user_monthlyIncome <= max_value:
            return min_val, max_val
income_min_limit, income_max_limit = get_income_limits(user_monthlyIncome)
#print(get_income_limits(1000, 3000)
filtr_1 = total_base['MonthlyIncome'] == user_monthlyIncome
filtr_2 = total_base['TotalWorkingYears'] == user_totalworkingyears
filtr_3 = total_base['EducationField'] == user_educationfield
filtr_4 = total_base['Education'] == user_education
df_1_filtr = total_base[filtr_1]
df_2_filtr = total_base[filtr_2]
df_3_filtr = total_base[filtr_3]
df_4_filtr = total_base[filtr_4]
print(df_1_filtr)
# Out:
# Jakie są Twoje wymarzone zarobki?:15000
# 10
# 'Medical'
# 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-dd4a1fd102ff> in <module>
#      18         if min_val < user_monthlyIncome <= max_value:
#      19             return min_val, max_val
# ---> 20 income_min_limit, income_max_limit = get_income_limits(user_monthlyIncome)
#      21 #print(get_income_limits(1000, 3000)
#      22 filtr_1 = (total_base['MonthlyIncome'] == user_monthlyIncome)
#
# <ipython-input-19-dd4a1fd102ff> in get_income_limits(user_monthlyIncome)
#      16     ]
#      17     for min_val, max_val in limits:
# ---> 18         if min_val < user_monthlyIncome <= max_value:
#      19             return min_val, max_val
#      20 income_min_limit, income_max_limit = get_income_limits(user_monthlyIncome)
#
# NameError: name 'max_value' is not defined

# %%
def monthlyincomee(data, min_value, max_value):
    filtr_1 = total_base['MonthlyIncome'] == user_monthlyIncome
    df_1_filtr = total_base[filtr_1]
    return filtr_1
print(monthlyincomee(df_1_filtr, 3000,5000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c86062e7fc57> in <module>
#       3     df_1_filtr = total_base[filtr_1]
#       4     return filtr_1
# ----> 5 print(monthlyincomee(df_1_filtr, 3000,5000))
#
# NameError: name 'df_1_filtr' is not defined

# %%
user_monthlyIncome = int(input('Jakie są Twoje wymarzone zarobki?:'))

print('Oto propozycje stanowisk dla Ciebie:')
if user_monthlyIncome >= 11001:
    df_1_filtr = total_base[filtr_1]
    filtr_1 = (total_base['MonthlyIncome'] == user_monthlyIncome)
else:
    print('nic')
# Out:
# Jakie są Twoje wymarzone zarobki?:12000
# Oto propozycje stanowisk dla Ciebie:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-8ee682e68f66> in <module>
#       3 print('Oto propozycje stanowisk dla Ciebie:')
#       4 if user_monthlyIncome >= 11001:
# ----> 5     df_1_filtr = total_base[filtr_1]
#       6     filtr_1 = (total_base['MonthlyIncome'] == user_monthlyIncome)
#       7 else:
#
# NameError: name 'filtr_1' is not defined
