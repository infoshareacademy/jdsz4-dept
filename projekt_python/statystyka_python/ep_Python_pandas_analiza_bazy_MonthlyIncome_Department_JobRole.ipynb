# %% [markdown]
# # Python (pandas): analiza bazy(MonthlyIncome->Department)

# %%
import pandas as pd
import os
import numpy as np
from matplotlib import pyplot

filename = "WA_Fn-UseC_-HR-Employee-Attrition.csv"
pyplot.rcParams.update({'font.size': 10})

# %%
file_path = "/Users/ela/Data Scientist - InfoshareAcademy/Python/WA_Fn-UseC_-HR-Employee-Attrition 3.csv"

# %%
data_frame = pd.read_csv(file_path)

# %% [markdown]
# ## Analiza bazy danych: IBM HR Analytics Employee Attrition & Performance

# %%
data_frame.shape
# Out:
# (1470, 35)

# %%
data_frame.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
print(type(data_frame))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### analiza atrybutu 'MonthlyIncome'

# %%
data_frame[["MonthlyIncome"]].describe()
# Out:
#        MonthlyIncome
# count    1470.000000
# mean     6502.931293
# std      4707.956783
# min      1009.000000
# 25%      2911.000000
# 50%      4919.000000
# 75%      8379.000000
# max     19999.000000

# %%
data_frame[["MonthlyIncome"]].hist(bins=20, alpha=0.8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1215ec748>]],
#       dtype=object)

# %% [markdown]
# ### analiza atrybutu 'Department'

# %%
data_frame[["Department"]].describe()
# Out:
#                     Department
# count                     1470
# unique                       3
# top     Research & Development
# freq                       961

# %%
data_frame.Department.unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %% [markdown]
# ### analiza atrybutu 'JobRole'

# %%
data_frame[["JobRole"]].describe()
# Out:
#                 JobRole
# count              1470
# unique                9
# top     Sales Executive
# freq                326

# %%
data_frame.JobRole.unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %% [markdown]
# ### analiza atrybutów: 'Department' i 'MonthlyIncome'

# %%
department_monthlyincome = data_frame[["Department", "MonthlyIncome"]]

# %% [markdown]
# #### Sales:

# %%
department_monthlyincome[(data_frame["Department"] == 'Sales') & (data_frame["MonthlyIncome"])]
# Out:
#      Department  MonthlyIncome
# 0         Sales           5993
# 18        Sales          15427
# 21        Sales           3407
# 27        Sales           6825
# 29        Sales          18947
# ...         ...            ...
# 1417      Sales           3067
# 1428      Sales           2269
# 1433      Sales           4907
# 1451      Sales           5343
# 1462      Sales          12031
#
# [213 rows x 2 columns]

# %%
department_monthlyincome[(data_frame["Department"] == 'Sales') & (data_frame["MonthlyIncome"])].describe()
# Out:
#        MonthlyIncome
# count     213.000000
# mean     7036.615023
# std      4399.354719
# min      1081.000000
# 25%      4373.000000
# 50%      5593.000000
# 75%      8865.000000
# max     19847.000000

# %% [markdown]
# #### R&D

# %%
department_monthlyincome[(data_frame["Department"] == 'Research & Development') & (data_frame["MonthlyIncome"])]
# Out:
#                   Department  MonthlyIncome
# 3     Research & Development           2909
# 7     Research & Development           2693
# 9     Research & Development           5237
# 11    Research & Development           4193
# 12    Research & Development           2911
# ...                      ...            ...
# 1458  Research & Development           2977
# 1459  Research & Development           4025
# 1460  Research & Development           3785
# 1465  Research & Development           2571
# 1466  Research & Development           9991
#
# [476 rows x 2 columns]

# %%
department_monthlyincome[(data_frame["Department"] == 'Research & Development') & (data_frame["MonthlyIncome"])].describe()
# Out:
#        MonthlyIncome
# count     476.000000
# mean     6274.155462
# std      4887.737927
# min      1009.000000
# 25%      2755.000000
# 50%      4481.000000
# 75%      7453.500000
# max     19999.000000

# %% [markdown]
# #### Human Resources

# %%
department_monthlyincome[(data_frame["Department"] == 'Human Resources') & (data_frame["MonthlyIncome"])]
# Out:
#            Department  MonthlyIncome
# 79    Human Resources           5021
# 100   Human Resources           2073
# 139   Human Resources           6347
# 232   Human Resources           2267
# 453   Human Resources           2741
# 493   Human Resources           5985
# 510   Human Resources          10725
# 535   Human Resources          19141
# 538   Human Resources          19189
# 551   Human Resources           6389
# 599   Human Resources           2143
# 613   Human Resources           3737
# 655   Human Resources           2277
# 759   Human Resources           2177
# 835   Human Resources           4323
# 943   Human Resources           3423
# 956   Human Resources          19717
# 999   Human Resources          16799
# 1035  Human Resources           2109
# 1096  Human Resources          16437
# 1107  Human Resources           6077
# 1165  Human Resources           5743
# 1200  Human Resources           3195
# 1222  Human Resources           1555
# ...

# %%
department_monthlyincome[(data_frame["Department"] == 'Human Resources') & (data_frame["MonthlyIncome"])].describe()
# Out:
#        MonthlyIncome
# count      32.000000
# mean     6204.937500
# std      5687.702762
# min      1555.000000
# 25%      2274.500000
# 50%      3638.000000
# 75%      6357.500000
# max     19717.000000
