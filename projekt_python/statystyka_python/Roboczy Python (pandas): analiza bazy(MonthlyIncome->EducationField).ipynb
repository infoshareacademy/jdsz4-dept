# %%
import pandas as pd

# %%
data_frame = pd.read_csv("/home/pawcio/Desktop/Projekty/tabele_zawody/WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
data_frame.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
educationfield.groupby('EducationField').describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-02a1fe935104> in <module>
# ----> 1 educationfield.groupby('EducationField').describe()
#
# NameError: name 'educationfield' is not defined

# %%
print(type(data_frame))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
arr_a = list([["Monthlyincome", "EducationField"]])
print(arr_a)
# Out:
# [['Monthlyincome', 'EducationField']]

# %%
print(type(educationfield['MonthlyIncome']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0594ef4bd3aa> in <module>
# ----> 1 print(type(educationfield['MonthlyIncome']))
#
# NameError: name 'educationfield' is not defined

# %%
print(list(data_frame.columns))
# Out:
# ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
data_frame['EducationField'].describe()
# Out:
# count              1470
# unique                6
# top       Life Sciences
# freq                606
# Name: EducationField, dtype: object

# %%
education_field = data_frame['EducationField']
monthly_in_come = data_frame['MonthlyIncome']

# %%
# histogram EducationField
education_field.hist()

# %%
# histogram MonthlyIncome
monthly_in_come.hist()

# %%
educationfield = (data_frame[['EducationField', 'MonthlyIncome']])
# print(educationfield)
total_base = (data_frame[['MonthlyIncome', 'EducationField', 'Education', 'TotalWorkingYears', 'Department', 'JobRole']])
#print(total_base)
lista_Monthlyincome = list(total_base['MonthlyIncome'])
lista_EducationField = list(total_base['EducationField'])
lista_Education = list(total_base['Education'])
lista_Department = list(total_base['Department'])
lista_TotalWorkingYears = list(total_base['TotalWorkingYears'])
lista_JobRole = list(total_base['JobRole'])
#lista_Mon_Edu = list(zip(lista_Monthlyincome, lista_EducationField))
# print(lista_Mon_Edu)
#print(sorted(lista_Mon_Edu, key = lambda x: x[1]))
total_list = sorted(list(zip(lista_Monthlyincome, lista_EducationField, lista_Education, lista_Department, lista_TotalWorkingYears, lista_JobRole)))
print(total_list)
#total_list_sorted = (sorted(total_list, key = lambda x: x[1]))
#total_list_sorted
# Out:
# [(1009, 'Medical', 1, 'Research & Development', 1, 'Research Scientist'), (1051, 'Life Sciences', 2, 'Research & Development', 0, 'Research Scientist'), (1052, 'Medical', 1, 'Sales', 1, 'Sales Representative'), (1081, 'Medical', 3, 'Sales', 1, 'Sales Representative'), (1091, 'Technical Degree', 3, 'Sales', 1, 'Sales Representative'), (1102, 'Life Sciences', 3, 'Research & Development', 1, 'Laboratory Technician'), (1118, 'Life Sciences', 1, 'Sales', 1, 'Sales Representative'), (1129, 'Medical', 1, 'Research & Development', 1, 'Laboratory Technician'), (1200, 'Medical', 3, 'Sales', 0, 'Sales Representative'), (1223, 'Life Sciences', 2, 'Research & Development', 1, 'Research Scientist'), (1232, 'Life Sciences', 2, 'Research & Development', 0, 'Research Scientist'), (1261, 'Life Sciences', 3, 'Research & Development', 1, 'Research Scientist'), (1274, 'Technical Degree', 3, 'Research & Development', 1, 'Research Scientist'), (1281, 'Life Sciences', 3, 'Research & Development', 1, 'Laboratory Technician'), (1359, 'Life Sciences', 4, 'Sales', 1, 'Sales Representative'), (1393, 'Life Sciences', 4, 'Research & Development', 1, 'Laboratory Technician'), (1416, 'Life Sciences', 3, 'Research & Development', 1, 'Laboratory Technician'), (1420, 'Life Sciences', 3, 'Research & Development', 0, 'Laboratory Technician'), (1483, 'Medical', 1, 'Research & Development', 1, 'Laboratory Technician'), (1514, 'Medical', 3, 'Research & Development', 0, 'Research Scientist'), (1555, 'Human Resources', 1, 'Human Resources', 1, 'Human Resources'), (1563, 'Life Sciences', 3, 'Research & Development', 1, 'Research Scientist'), (1569, 'Medical', 2, 'Sales', 0, 'Sales Representative'), (1601, 'Life Sciences', 3, 'Research & Development', 1, 'Laboratory Technician'), (1611, 'Life Sciences', 3, 'Research & Development', 0, 'Laboratory Technician'), (1675, 'Marketing', 1, 'Sales', 0, 'Sales Representative'), (1702, 'Life Sciences', 2, 'Research & Development', 1, 'Laboratory Technician'), (1706, 'Medical', 3, 'Research & Development', 0, 'Research Scientist'), (1790, 'Marketing', 3, 'Sales', 1, 'Sales Representative'), (1859, 'Medical', 3, 'Research & Development', 1, 'Research Scientist'), (1878, 'Marketing', 3, 'Sales', 0, 'Sales Representative'), (1904, 'Medical', 1, 'Research & Development', 0, 'Laboratory Technician'), (1951, 'Other', 2, 'Research & Development', 1, 'Laboratory Technician'), (2001, 'Medical', 4, 'Research & Development', 20, 'Research Scientist'), (2007, 'Medical', 1, 'Research & Development', 5, 'Research Scientist'), (2008, 'Life Sciences', 3, 'Research & Development', 1, 'Laboratory Technician'), (2008, 'Medical', 2, 'Research & Development', 1, 'Laboratory Technician'), (2011, 'Life Sciences', 1, 'Research & Development', 10, 'Research Scientist'), (2013, 'Life Sciences', 3, 'Research & Development', 15, 'Laboratory Technician'), (2014, 'Marketing', 3, 'Sales', 2, 'Sales Representative'), (2018, 'Life Sciences', 4, 'Research & Development', 15, 'Laboratory Technician'), (2022, 'Life Sciences', 4, 'Research & Development', 10, 'Research Scientist'), (2024, 'Medical', 3, 'Research & Development', 6, 'Research Scientist'), (2028, 'Life Sciences', 3, 'Research & Development', 6, 'Laboratory Technician'), (2028, 'Medical', 3, 'Research & Development', 14, 'Laboratory Technician'), (2029, 'Technical Degree', 1, 'Research & Development', 5, 'Research Scientist'), (2033, 'Life Sciences', 2, 'Sales', 1, 'Sales Representative'), (2033, 'Life Sciences', 4, 'Sales', 1, 'Sales Representative'), (2042, 'Life Sciences', 3, 'Research & Development', 6, 'Research Scientist'), (2042, 'Medical', 3, 'Research & Development', 17, 'Laboratory Technician'), (2044, 'Life Sciences', 3, 'Research & Development', 5, 'Research Scientist'), (2044, 'Medical', 3, 'Sales', 2, 'Sales Representative'), (2045, 'Medical', 4, 'Research & Development', 5, 'Research Scientist'), (2058, 'Technical Degree', 3, 'Research & Development', 7, 'Research Scientist'), (2061, 'Life  ...
# [(1555, 'Human Resources', 1, 'Human Resources', 1, 'Human Resources'),
#  (2073, 'Human Resources', 4, 'Human Resources', 7, 'Human Resources'),
#  (2143, 'Human Resources', 3, 'Human Resources', 8, 'Human Resources'),
#  (2180, 'Human Resources', 3, 'Human Resources', 6, 'Human Resources'),
#  (2187, 'Human Resources', 3, 'Human Resources', 6, 'Human Resources'),
#  (2277, 'Human Resources', 2, 'Human Resources', 7, 'Human Resources'),
#  (2335, 'Human Resources', 3, 'Human Resources', 4, 'Human Resources'),
#  (2592, 'Human Resources', 3, 'Human Resources', 13, 'Human Resources'),
#  (2844, 'Human Resources', 3, 'Human Resources', 7, 'Human Resources'),
#  (2863, 'Human Resources', 3, 'Human Resources', 1, 'Human Resources'),
#  (2956, 'Human Resources', 5, 'Human Resources', 2, 'Human Resources'),
#  (3600, 'Human Resources', 3, 'Human Resources', 5, 'Human Resources'),
#  (3737, 'Human Resources', 2, 'Human Resources', 4, 'Human Resources'),
#  (3886, 'Human Resources', 1, 'Human Resources', 10, 'Human Resources'),
#  (5743, 'Human Resources', 5, 'Human Resources', 14, 'Human Resources'),
#  (6077, 'Human Resources', 4, 'Human Resources', 10, 'Human Resources'),
#  (6347, 'Human Resources', 3, 'Human Resources', 12, 'Human Resources'),
#  (6389, 'Human Resources', 3, 'Human Resources', 12, 'Human Resources'),
#  (6410, 'Human Resources', 3, 'Human Resources', 9, 'Human Resources'),
#  (6430, 'Human Resources', 3, 'Human Resources', 10, 'Human Resources'),
#  (9950, 'Human Resources', 3, 'Human Resources', 11, 'Human Resources'),
#  (16799, 'Human Resources', 3, 'Human Resources', 21, 'Manager'),
#  (17328, 'Human Resources', 3, 'Human Resources', 23, 'Manager'),
#  (18844, 'Human Resources', 4, 'Human Resources', 30, 'Manager'),
#  (19141, 'Human Resources', 4, 'Human Resources', 23, 'Manager'),
#  (19189, 'Human Resources', 3, 'Human Resources', 22, 'Manager'),
#  (19636, 'Human Resources', 4, 'Human Resources', 35, 'Manager'),
#  (1051, 'Life Sciences', 2, 'Research & Development', 0, 'Research Scientist'),
#  (1102,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (1118, 'Life Sciences', 1, 'Sales', 1, 'Sales Representative'),
#  (1223, 'Life Sciences', 2, 'Research & Development', 1, 'Research Scientist'),
#  (1232, 'Life Sciences', 2, 'Research & Development', 0, 'Research Scientist'),
#  (1261, 'Life Sciences', 3, 'Research & Development', 1, 'Research Scientist'),
#  (1281,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (1359, 'Life Sciences', 4, 'Sales', 1, 'Sales Representative'),
#  (1393,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (1416,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (1420,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   0,
#   'Laboratory Technician'),
#  (1563, 'Life Sciences', 3, 'Research & Development', 1, 'Research Scientist'),
#  (1601,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (1611,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   0,
#   'Laboratory Technician'),
#  (1702,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (2008,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (2011,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (2013,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   15,
#   'Laboratory Technician'),
#  (2018,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   15,
#   'Laboratory Technician'),
#  (2022,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (2028,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   6,
#   'Laboratory Technician'),
#  (2033, 'Life Sciences', 2, 'Sales', 1, 'Sales Representative'),
#  (2033, 'Life Sciences', 4, 'Sales', 1, 'Sales Representative'),
#  (2042, 'Life Sciences', 3, 'Research & Development', 6, 'Research Scientist'),
#  (2044, 'Life Sciences', 3, 'Research & Development', 5, 'Research Scientist'),
#  (2061, 'Life Sciences', 3, 'Research & Development', 1, 'Research Scientist'),
#  (2062,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   11,
#   'Laboratory Technician'),
#  (2064, 'Life Sciences', 3, 'Human Resources', 6, 'Human Resources'),
#  (2066, 'Life Sciences', 2, 'Research & Development', 5, 'Research Scientist'),
#  (2074,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (2075,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (2097,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   9,
#   'Laboratory Technician'),
#  (2099,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   6,
#   'Laboratory Technician'),
#  (2105,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   7,
#   'Laboratory Technician'),
#  (2107, 'Life Sciences', 2, 'Research & Development', 5, 'Research Scientist'),
#  (2115,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   17,
#   'Research Scientist'),
#  (2132, 'Life Sciences', 3, 'Research & Development', 7, 'Research Scientist'),
#  (2166,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (2168, 'Life Sciences', 1, 'Research & Development', 6, 'Research Scientist'),
#  (2177, 'Life Sciences', 3, 'Research & Development', 7, 'Research Scientist'),
#  (2201, 'Life Sciences', 3, 'Research & Development', 6, 'Research Scientist'),
#  (2207,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   4,
#   'Laboratory Technician'),
#  (2210,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (2213,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (2216,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (2218,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   4,
#   'Laboratory Technician'),
#  (2220, 'Life Sciences', 4, 'Sales', 1, 'Sales Representative'),
#  (2235, 'Life Sciences', 3, 'Research & Development', 9, 'Research Scientist'),
#  (2238,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   7,
#   'Laboratory Technician'),
#  (2269,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (2272,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   5,
#   'Laboratory Technician'),
#  (2274, 'Life Sciences', 3, 'Research & Development', 1, 'Research Scientist'),
#  (2275, 'Life Sciences', 3, 'Sales', 3, 'Sales Representative'),
#  (2288,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   2,
#   'Laboratory Technician'),
#  (2289,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   5,
#   'Laboratory Technician'),
#  (2290, 'Life Sciences', 3, 'Research & Development', 6, 'Research Scientist'),
#  (2293,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (2302, 'Life Sciences', 3, 'Sales', 3, 'Sales Representative'),
#  (2314,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   4,
#   'Laboratory Technician'),
#  (2318, 'Life Sciences', 3, 'Research & Development', 1, 'Research Scientist'),
#  (2319,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (2328, 'Life Sciences', 3, 'Research & Development', 4, 'Research Scientist'),
#  (2329, 'Life Sciences', 4, 'Sales', 13, 'Sales Representative'),
#  (2332,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   5,
#   'Laboratory Technician'),
#  (2340, 'Life Sciences', 3, 'Research & Development', 6, 'Research Scientist'),
#  (2341,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (2342, 'Life Sciences', 1, 'Sales', 3, 'Sales Representative'),
#  (2342, 'Life Sciences', 3, 'Human Resources', 6, 'Human Resources'),
#  (2348,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   20,
#   'Laboratory Technician'),
#  (2356, 'Life Sciences', 4, 'Research & Development', 8, 'Research Scientist'),
#  (2362,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (2372, 'Life Sciences', 4, 'Research & Development', 2, 'Research Scientist'),
#  (2379,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   6,
#   'Laboratory Technician'),
#  (2380,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   3,
#   'Laboratory Technician'),
#  (2380,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   8,
#   'Laboratory Technician'),
#  (2387,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   7,
#   'Laboratory Technician'),
#  (2394, 'Life Sciences', 4, 'Research & Development', 8, 'Research Scientist'),
#  (2404, 'Life Sciences', 1, 'Sales', 1, 'Sales Representative'),
#  (2404, 'Life Sciences', 3, 'Research & Development', 3, 'Research Scientist'),
#  (2406,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   8,
#   'Laboratory Technician'),
#  (2406,
#   'Life Sciences',
#   5,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (2430, 'Life Sciences', 4, 'Sales', 6, 'Sales Representative'),
#  (2432, 'Life Sciences', 2, 'Research & Development', 8, 'Research Scientist'),
#  (2438, 'Life Sciences', 3, 'Research & Development', 7, 'Research Scientist'),
#  (2439, 'Life Sciences', 2, 'Research & Development', 1, 'Research Scientist'),
#  (2450,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   19,
#   'Laboratory Technician'),
#  (2451,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   4,
#   'Laboratory Technician'),
#  (2451, 'Life Sciences', 3, 'Research & Development', 5, 'Research Scientist'),
#  (2451,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   13,
#   'Research Scientist'),
#  (2455,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   9,
#   'Laboratory Technician'),
#  (2461,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   18,
#   'Research Scientist'),
#  (2472, 'Life Sciences', 1, 'Research & Development', 1, 'Research Scientist'),
#  (2478, 'Life Sciences', 3, 'Research & Development', 4, 'Research Scientist'),
#  (2500, 'Life Sciences', 3, 'Research & Development', 4, 'Research Scientist'),
#  (2506, 'Life Sciences', 4, 'Research & Development', 7, 'Research Scientist'),
#  (2514,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   11,
#   'Research Scientist'),
#  (2515,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (2517, 'Life Sciences', 2, 'Research & Development', 5, 'Research Scientist'),
#  (2539, 'Life Sciences', 3, 'Research & Development', 4, 'Research Scientist'),
#  (2543, 'Life Sciences', 3, 'Research & Development', 6, 'Research Scientist'),
#  (2552, 'Life Sciences', 2, 'Research & Development', 1, 'Research Scientist'),
#  (2553, 'Life Sciences', 4, 'Research & Development', 6, 'Research Scientist'),
#  (2559, 'Life Sciences', 2, 'Research & Development', 8, 'Research Scientist'),
#  (2572, 'Life Sciences', 4, 'Sales', 3, 'Sales Representative'),
#  (2576,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   8,
#   'Laboratory Technician'),
#  (2587,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   5,
#   'Laboratory Technician'),
#  (2610, 'Life Sciences', 3, 'Research & Development', 4, 'Research Scientist'),
#  (2613,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (2619, 'Life Sciences', 1, 'Research & Development', 8, 'Research Scientist'),
#  (2625,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   2,
#   'Laboratory Technician'),
#  (2632, 'Life Sciences', 3, 'Research & Development', 5, 'Research Scientist'),
#  (2642, 'Life Sciences', 3, 'Sales', 1, 'Sales Representative'),
#  (2644, 'Life Sciences', 4, 'Sales', 7, 'Sales Representative'),
#  (2654, 'Life Sciences', 2, 'Research & Development', 8, 'Research Scientist'),
#  (2657, 'Life Sciences', 4, 'Research & Development', 3, 'Research Scientist'),
#  (2659,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   3,
#   'Laboratory Technician'),
#  (2690,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (2691,
#   'Life Sciences',
#   5,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (2693,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (2694,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (2695, 'Life Sciences', 4, 'Research & Development', 3, 'Research Scientist'),
#  (2700,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (2703, 'Life Sciences', 3, 'Research & Development', 3, 'Research Scientist'),
#  (2703, 'Life Sciences', 3, 'Research & Development', 6, 'Research Scientist'),
#  (2706, 'Life Sciences', 2, 'Human Resources', 3, 'Human Resources'),
#  (2707,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   13,
#   'Laboratory Technician'),
#  (2716, 'Life Sciences', 3, 'Sales', 1, 'Sales Representative'),
#  (2720,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (2723, 'Life Sciences', 3, 'Research & Development', 1, 'Research Scientist'),
#  (2728, 'Life Sciences', 1, 'Sales', 2, 'Sales Representative'),
#  (2741, 'Life Sciences', 4, 'Human Resources', 8, 'Human Resources'),
#  (2741,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   7,
#   'Laboratory Technician'),
#  (2743,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   18,
#   'Laboratory Technician'),
#  (2768,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   14,
#   'Research Scientist'),
#  (2774,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   6,
#   'Laboratory Technician'),
#  (2778,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (2782, 'Life Sciences', 1, 'Research & Development', 6, 'Research Scientist'),
#  (2782,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   12,
#   'Research Scientist'),
#  (2785, 'Life Sciences', 3, 'Sales', 3, 'Sales Representative'),
#  (2791, 'Life Sciences', 3, 'Sales', 3, 'Sales Representative'),
#  (2794,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   5,
#   'Laboratory Technician'),
#  (2795,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (2809, 'Life Sciences', 4, 'Research & Development', 8, 'Research Scientist'),
#  (2810,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   5,
#   'Laboratory Technician'),
#  (2818,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (2827, 'Life Sciences', 1, 'Sales', 1, 'Sales Representative'),
#  (2835,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   7,
#   'Laboratory Technician'),
#  (2836, 'Life Sciences', 3, 'Research & Development', 1, 'Research Scientist'),
#  (2837,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   6,
#   'Laboratory Technician'),
#  (2853, 'Life Sciences', 4, 'Research & Development', 1, 'Research Scientist'),
#  (2858, 'Life Sciences', 3, 'Sales', 20, 'Sales Representative'),
#  (2862,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (2875, 'Life Sciences', 2, 'Research & Development', 8, 'Research Scientist'),
#  (2886, 'Life Sciences', 3, 'Research & Development', 3, 'Research Scientist'),
#  (2886,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   6,
#   'Laboratory Technician'),
#  (2897, 'Life Sciences', 2, 'Research & Development', 9, 'Research Scientist'),
#  (2904, 'Life Sciences', 1, 'Research & Development', 4, 'Research Scientist'),
#  (2909, 'Life Sciences', 4, 'Research & Development', 8, 'Research Scientist'),
#  (2911, 'Life Sciences', 1, 'Research & Development', 5, 'Research Scientist'),
#  (2911, 'Life Sciences', 4, 'Research & Development', 2, 'Research Scientist'),
#  (2926,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   1,
#   'Laboratory Technician'),
#  (2929,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (2933, 'Life Sciences', 2, 'Research & Development', 1, 'Research Scientist'),
#  (2936, 'Life Sciences', 4, 'Research & Development', 6, 'Research Scientist'),
#  (2942, 'Life Sciences', 1, 'Human Resources', 8, 'Human Resources'),
#  (2956, 'Life Sciences', 1, 'Research & Development', 1, 'Research Scientist'),
#  (2977, 'Life Sciences', 4, 'Research & Development', 4, 'Research Scientist'),
#  (2979, 'Life Sciences', 4, 'Research & Development', 6, 'Research Scientist'),
#  (2994, 'Life Sciences', 3, 'Research & Development', 1, 'Research Scientist'),
#  (2996, 'Life Sciences', 1, 'Research & Development', 8, 'Research Scientist'),
#  (3022, 'Life Sciences', 2, 'Research & Development', 8, 'Research Scientist'),
#  (3033,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   2,
#   'Laboratory Technician'),
#  (3034,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   18,
#   'Laboratory Technician'),
#  (3038,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   5,
#   'Laboratory Technician'),
#  (3038, 'Life Sciences', 5, 'Research & Development', 8, 'Research Scientist'),
#  (3067, 'Life Sciences', 2, 'Sales', 3, 'Sales Representative'),
#  (3068,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   8,
#   'Laboratory Technician'),
#  (3072,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   17,
#   'Research Scientist'),
#  (3143,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   14,
#   'Research Scientist'),
#  (3149,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   9,
#   'Laboratory Technician'),
#  (3161,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   19,
#   'Laboratory Technician'),
#  (3162,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   6,
#   'Laboratory Technician'),
#  (3162,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   7,
#   'Laboratory Technician'),
#  (3180,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   4,
#   'Laboratory Technician'),
#  (3195, 'Life Sciences', 3, 'Human Resources', 8, 'Human Resources'),
#  (3201, 'Life Sciences', 1, 'Research & Development', 6, 'Research Scientist'),
#  (3210,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   16,
#   'Laboratory Technician'),
#  (3211,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (3212,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   6,
#   'Laboratory Technician'),
#  (3280,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (3291, 'Life Sciences', 3, 'Research & Development', 8, 'Research Scientist'),
#  (3294,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   7,
#   'Laboratory Technician'),
#  (3294, 'Life Sciences', 4, 'Sales', 3, 'Sales Representative'),
#  (3298, 'Life Sciences', 2, 'Research & Development', 7, 'Research Scientist'),
#  (3310, 'Life Sciences', 2, 'Research & Development', 5, 'Research Scientist'),
#  (3348,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (3375, 'Life Sciences', 2, 'Research & Development', 4, 'Research Scientist'),
#  (3377,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   7,
#   'Laboratory Technician'),
#  (3407,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (3407, 'Life Sciences', 4, 'Sales', 10, 'Sales Representative'),
#  (3419, 'Life Sciences', 4, 'Research & Development', 6, 'Research Scientist'),
#  (3420, 'Life Sciences', 3, 'Research & Development', 6, 'Research Scientist'),
#  (3423, 'Life Sciences', 2, 'Human Resources', 10, 'Human Resources'),
#  (3433,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (3452, 'Life Sciences', 1, 'Research & Development', 5, 'Research Scientist'),
#  (3477,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   6,
#   'Laboratory Technician'),
#  (3482, 'Life Sciences', 4, 'Sales', 16, 'Sales Representative'),
#  (3485,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   5,
#   'Laboratory Technician'),
#  (3491,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (3506, 'Life Sciences', 1, 'Research & Development', 4, 'Research Scientist'),
#  (3539, 'Life Sciences', 3, 'Human Resources', 10, 'Human Resources'),
#  (3544, 'Life Sciences', 2, 'Research & Development', 6, 'Research Scientist'),
#  (3564, 'Life Sciences', 3, 'Research & Development', 8, 'Research Scientist'),
#  (3622, 'Life Sciences', 2, 'Research & Development', 6, 'Research Scientist'),
#  (3633,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   9,
#   'Laboratory Technician'),
#  (3646,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   11,
#   'Laboratory Technician'),
#  (3688,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   4,
#   'Laboratory Technician'),
#  (3722,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   7,
#   'Laboratory Technician'),
#  (3730,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   4,
#   'Laboratory Technician'),
#  (3755,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   8,
#   'Laboratory Technician'),
#  (3760, 'Life Sciences', 3, 'Research & Development', 3, 'Research Scientist'),
#  (3761,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (3780,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   19,
#   'Laboratory Technician'),
#  (3833,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   7,
#   'Laboratory Technician'),
#  (3867,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   2,
#   'Laboratory Technician'),
#  (3919,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (3931, 'Life Sciences', 2, 'Sales', 6, 'Sales Representative'),
#  (3944, 'Life Sciences', 3, 'Research & Development', 6, 'Research Scientist'),
#  (3968,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   8,
#   'Laboratory Technician'),
#  (4000,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   6,
#   'Healthcare Representative'),
#  (4001, 'Life Sciences', 3, 'Sales', 15, 'Sales Executive'),
#  (4014,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   10,
#   'Healthcare Representative'),
#  (4033,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   5,
#   'Manufacturing Director'),
#  (4035,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   4,
#   'Healthcare Representative'),
#  (4069,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   8,
#   'Healthcare Representative'),
#  (4084, 'Life Sciences', 3, 'Research & Development', 7, 'Research Scientist'),
#  (4089,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Healthcare Representative'),
#  (4108,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   18,
#   'Research Scientist'),
#  (4115, 'Life Sciences', 4, 'Sales', 8, 'Sales Executive'),
#  (4127, 'Life Sciences', 3, 'Sales', 7, 'Sales Executive'),
#  (4148,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   4,
#   'Manufacturing Director'),
#  (4148,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   15,
#   'Healthcare Representative'),
#  (4152,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   11,
#   'Healthcare Representative'),
#  (4163, 'Life Sciences', 2, 'Sales', 9, 'Sales Executive'),
#  (4171,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   4,
#   'Manufacturing Director'),
#  (4193,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (4197,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (4197,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   18,
#   'Manufacturing Director'),
#  (4198, 'Life Sciences', 3, 'Sales', 8, 'Sales Executive'),
#  (4227,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   4,
#   'Manufacturing Director'),
#  (4230,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   6,
#   'Laboratory Technician'),
#  (4240,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   19,
#   'Healthcare Representative'),
#  (4249, 'Life Sciences', 4, 'Research & Development', 9, 'Research Scientist'),
#  (4257,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   19,
#   'Research Scientist'),
#  (4284,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   20,
#   'Laboratory Technician'),
#  (4286, 'Life Sciences', 4, 'Sales', 5, 'Sales Executive'),
#  (4302, 'Life Sciences', 3, 'Sales', 4, 'Sales Executive'),
#  (4320,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   5,
#   'Manufacturing Director'),
#  (4332,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   20,
#   'Research Scientist'),
#  (4364,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   5,
#   'Laboratory Technician'),
#  (4400, 'Life Sciences', 2, 'Sales', 6, 'Sales Representative'),
#  (4403, 'Life Sciences', 4, 'Sales', 8, 'Sales Executive'),
#  (4424,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   11,
#   'Manufacturing Director'),
#  (4434,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Manufacturing Director'),
#  (4440, 'Life Sciences', 4, 'Sales', 16, 'Sales Executive'),
#  (4447,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   9,
#   'Laboratory Technician'),
#  (4448,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   15,
#   'Healthcare Representative'),
#  (4478, 'Life Sciences', 3, 'Sales', 5, 'Sales Executive'),
#  (4487, 'Life Sciences', 2, 'Sales', 5, 'Sales Executive'),
#  (4490, 'Life Sciences', 3, 'Human Resources', 14, 'Human Resources'),
#  (4502, 'Life Sciences', 4, 'Sales', 17, 'Sales Representative'),
#  (4505,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   12,
#   'Research Scientist'),
#  (4534,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   9,
#   'Manufacturing Director'),
#  (4554, 'Life Sciences', 2, 'Sales', 10, 'Sales Executive'),
#  (4556,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   19,
#   'Research Scientist'),
#  (4559, 'Life Sciences', 3, 'Sales', 4, 'Sales Executive'),
#  (4577, 'Life Sciences', 2, 'Sales', 4, 'Sales Executive'),
#  (4615,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   19,
#   'Research Scientist'),
#  (4617,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   4,
#   'Healthcare Representative'),
#  (4621,
#   'Life Sciences',
#   5,
#   'Research & Development',
#   3,
#   'Laboratory Technician'),
#  (4639, 'Life Sciences', 2, 'Sales', 5, 'Sales Executive'),
#  (4649, 'Life Sciences', 3, 'Sales', 4, 'Sales Executive'),
#  (4661, 'Life Sciences', 3, 'Research & Development', 9, 'Research Scientist'),
#  (4663,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   7,
#   'Manufacturing Director'),
#  (4680, 'Life Sciences', 2, 'Research & Development', 4, 'Research Scientist'),
#  (4724, 'Life Sciences', 3, 'Sales', 5, 'Sales Executive'),
#  (4724,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   9,
#   'Manufacturing Director'),
#  (4735,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   19,
#   'Research Scientist'),
#  (4765,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   4,
#   'Manufacturing Director'),
#  (4766,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   6,
#   'Laboratory Technician'),
#  (4771,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (4774, 'Life Sciences', 3, 'Research & Development', 8, 'Research Scientist'),
#  (4775,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   4,
#   'Manufacturing Director'),
#  (4850, 'Life Sciences', 3, 'Sales', 8, 'Sales Executive'),
#  (4851, 'Life Sciences', 3, 'Sales', 4, 'Sales Executive'),
#  (4869,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   20,
#   'Research Scientist'),
#  (4876,
#   'Life Sciences',
#   5,
#   'Research & Development',
#   5,
#   'Healthcare Representative'),
#  (4883,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (4898,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   5,
#   'Manufacturing Director'),
#  (4898, 'Life Sciences', 3, 'Sales', 5, 'Sales Executive'),
#  (4900,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   13,
#   'Research Scientist'),
#  (4907, 'Life Sciences', 1, 'Sales', 20, 'Sales Executive'),
#  (4936, 'Life Sciences', 2, 'Sales', 18, 'Sales Executive'),
#  (4950, 'Life Sciences', 4, 'Sales', 5, 'Sales Executive'),
#  (4963, 'Life Sciences', 4, 'Research & Development', 7, 'Research Scientist'),
#  (4998,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (5003,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (5006, 'Life Sciences', 2, 'Sales', 9, 'Sales Executive'),
#  (5033,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Healthcare Representative'),
#  (5071, 'Life Sciences', 1, 'Sales', 8, 'Sales Executive'),
#  (5093,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   16,
#   'Healthcare Representative'),
#  (5121,
#   'Life Sciences',
#   5,
#   'Research & Development',
#   7,
#   'Manufacturing Director'),
#  (5126,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (5130,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (5131,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   18,
#   'Manufacturing Director'),
#  (5154, 'Life Sciences', 4, 'Sales', 10, 'Sales Executive'),
#  (5163,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   17,
#   'Healthcare Representative'),
#  (5171, 'Life Sciences', 3, 'Sales', 13, 'Sales Executive'),
#  (5204, 'Life Sciences', 3, 'Human Resources', 13, 'Human Resources'),
#  (5204, 'Life Sciences', 4, 'Sales', 10, 'Sales Executive'),
#  (5206,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   7,
#   'Manufacturing Director'),
#  (5207,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   15,
#   'Laboratory Technician'),
#  (5208,
#   'Life Sciences',
#   5,
#   'Research & Development',
#   16,
#   'Research Scientist'),
#  (5210,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   24,
#   'Laboratory Technician'),
#  (5231,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   17,
#   'Laboratory Technician'),
#  (5249, 'Life Sciences', 2, 'Sales', 13, 'Sales Executive'),
#  (5253, 'Life Sciences', 4, 'Sales', 7, 'Sales Executive'),
#  (5257,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   9,
#   'Laboratory Technician'),
#  (5294,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Healthcare Representative'),
#  (5296, 'Life Sciences', 3, 'Sales', 8, 'Sales Executive'),
#  (5301, 'Life Sciences', 1, 'Sales', 4, 'Sales Executive'),
#  (5309,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (5321,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Manufacturing Director'),
#  (5337, 'Life Sciences', 4, 'Sales', 10, 'Sales Executive'),
#  (5343, 'Life Sciences', 2, 'Sales', 10, 'Sales Executive'),
#  (5346,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   11,
#   'Laboratory Technician'),
#  (5347,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Healthcare Representative'),
#  (5368, 'Life Sciences', 3, 'Sales', 7, 'Sales Executive'),
#  (5373,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   6,
#   'Healthcare Representative'),
#  (5376, 'Life Sciences', 3, 'Sales', 10, 'Sales Executive'),
#  (5381,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   23,
#   'Laboratory Technician'),
#  (5410, 'Life Sciences', 4, 'Research & Development', 9, 'Research Scientist'),
#  (5410,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   18,
#   'Manufacturing Director'),
#  (5433,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   11,
#   'Research Scientist'),
#  (5467,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   12,
#   'Research Scientist'),
#  (5473, 'Life Sciences', 1, 'Sales', 20, 'Sales Executive'),
#  (5476, 'Life Sciences', 4, 'Sales', 10, 'Sales Executive'),
#  (5484, 'Life Sciences', 3, 'Sales', 13, 'Sales Executive'),
#  (5484, 'Life Sciences', 4, 'Research & Development', 9, 'Research Scientist'),
#  (5562,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   12,
#   'Healthcare Representative'),
#  (5562,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   9,
#   'Laboratory Technician'),
#  (5562,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   19,
#   'Healthcare Representative'),
#  (5593, 'Life Sciences', 4, 'Sales', 15, 'Sales Executive'),
#  (5660,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   12,
#   'Healthcare Representative'),
#  (5674,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   11,
#   'Laboratory Technician'),
#  (5675, 'Life Sciences', 4, 'Sales', 7, 'Sales Executive'),
#  (5689,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Healthcare Representative'),
#  (5714, 'Life Sciences', 1, 'Sales', 6, 'Sales Executive'),
#  (5736, 'Life Sciences', 4, 'Sales', 10, 'Sales Executive'),
#  (5745,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Healthcare Representative'),
#  (5768,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   9,
#   'Manufacturing Director'),
#  (5810,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (5813, 'Life Sciences', 3, 'Sales', 10, 'Sales Executive'),
#  (5878,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   12,
#   'Research Scientist'),
#  (5902, 'Life Sciences', 4, 'Sales', 17, 'Sales Executive'),
#  (5906,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   10,
#   'Manufacturing Director'),
#  (5914,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   16,
#   'Laboratory Technician'),
#  (5915,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (5916,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   8,
#   'Manufacturing Director'),
#  (5957,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   13,
#   'Manufacturing Director'),
#  (5968,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   9,
#   'Healthcare Representative'),
#  (5980,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   17,
#   'Manufacturing Director'),
#  (5985, 'Life Sciences', 4, 'Human Resources', 10, 'Human Resources'),
#  (5993, 'Life Sciences', 2, 'Sales', 8, 'Sales Executive'),
#  (5993,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   7,
#   'Manufacturing Director'),
#  (6029, 'Life Sciences', 2, 'Sales', 6, 'Sales Executive'),
#  (6062,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   8,
#   'Manufacturing Director'),
#  (6074,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   9,
#   'Laboratory Technician'),
#  (6091,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   11,
#   'Manufacturing Director'),
#  (6120, 'Life Sciences', 4, 'Sales', 8, 'Sales Executive'),
#  (6142,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   6,
#   'Manufacturing Director'),
#  (6162,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   14,
#   'Manufacturing Director'),
#  (6172, 'Life Sciences', 4, 'Sales', 12, 'Sales Executive'),
#  (6201, 'Life Sciences', 2, 'Sales', 18, 'Sales Executive'),
#  (6220,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (6230, 'Life Sciences', 2, 'Sales', 16, 'Sales Executive'),
#  (6232, 'Life Sciences', 1, 'Sales', 6, 'Sales Executive'),
#  (6288,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   13,
#   'Healthcare Representative'),
#  (6294,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Healthcare Representative'),
#  (6306,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   13,
#   'Healthcare Representative'),
#  (6322, 'Life Sciences', 4, 'Research & Development', 6, 'Research Scientist'),
#  (6347, 'Life Sciences', 3, 'Sales', 19, 'Sales Executive'),
#  (6384,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   11,
#   'Healthcare Representative'),
#  (6388,
#   'Life Sciences',
#   5,
#   'Research & Development',
#   14,
#   'Healthcare Representative'),
#  (6392, 'Life Sciences', 4, 'Sales', 8, 'Sales Executive'),
#  (6397, 'Life Sciences', 2, 'Sales', 8, 'Sales Executive'),
#  (6397,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   6,
#   'Manufacturing Director'),
#  (6434,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   9,
#   'Manufacturing Director'),
#  (6439, 'Life Sciences', 4, 'Sales', 18, 'Sales Executive'),
#  (6447,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   8,
#   'Manufacturing Director'),
#  (6472,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   9,
#   'Laboratory Technician'),
#  (6474,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   14,
#   'Manufacturing Director'),
#  (6499,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   6,
#   'Manufacturing Director'),
#  (6500, 'Life Sciences', 2, 'Sales', 6, 'Sales Executive'),
#  (6513,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   12,
#   'Healthcare Representative'),
#  (6516,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   18,
#   'Manufacturing Director'),
#  (6524, 'Life Sciences', 2, 'Sales', 10, 'Sales Executive'),
#  (6540,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Healthcare Representative'),
#  (6545,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   10,
#   'Research Scientist'),
#  (6549,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   8,
#   'Manufacturing Director'),
#  (6553,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   14,
#   'Manufacturing Director'),
#  (6582, 'Life Sciences', 1, 'Sales', 10, 'Sales Executive'),
#  (6586,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   17,
#   'Healthcare Representative'),
#  (6623,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   6,
#   'Healthcare Representative'),
#  (6646,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   17,
#   'Research Scientist'),
#  (6674,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Laboratory Technician'),
#  (6694, 'Life Sciences', 4, 'Sales', 8, 'Sales Executive'),
#  (6728, 'Life Sciences', 4, 'Sales', 12, 'Sales Executive'),
#  (6735, 'Life Sciences', 2, 'Sales', 10, 'Sales Executive'),
#  (6782,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   9,
#   'Laboratory Technician'),
#  (6804, 'Life Sciences', 3, 'Sales', 7, 'Sales Executive'),
#  (6804,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   7,
#   'Manufacturing Director'),
#  (6815, 'Life Sciences', 4, 'Sales', 15, 'Sales Executive'),
#  (6834, 'Life Sciences', 2, 'Sales', 7, 'Sales Executive'),
#  (6842,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   13,
#   'Healthcare Representative'),
#  (6861, 'Life Sciences', 4, 'Sales', 19, 'Sales Executive'),
#  (6870,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   11,
#   'Healthcare Representative'),
#  (6883,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   17,
#   'Manufacturing Director'),
#  (6893, 'Life Sciences', 2, 'Sales', 11, 'Sales Executive'),
#  (6949,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   6,
#   'Healthcare Representative'),
#  (7082, 'Life Sciences', 2, 'Sales', 21, 'Sales Executive'),
#  (7119,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   9,
#   'Healthcare Representative'),
#  (7260,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   37,
#   'Manufacturing Director'),
#  (7314, 'Life Sciences', 3, 'Sales', 14, 'Sales Executive'),
#  (7336, 'Life Sciences', 1, 'Sales', 11, 'Sales Executive'),
#  (7412,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   9,
#   'Manufacturing Director'),
#  (7428, 'Life Sciences', 3, 'Sales', 12, 'Sales Executive'),
#  (7446,
#   'Life Sciences',
#   5,
#   'Research & Development',
#   10,
#   'Manufacturing Director'),
#  (7510,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Healthcare Representative'),
#  (7587, 'Life Sciences', 4, 'Sales', 10, 'Sales Executive'),
#  (7625,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Healthcare Representative'),
#  (7632,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Healthcare Representative'),
#  (7637, 'Life Sciences', 3, 'Sales', 28, 'Sales Executive'),
#  (7725,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   15,
#   'Healthcare Representative'),
#  (7756,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   7,
#   'Healthcare Representative'),
#  (7779,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   18,
#   'Manufacturing Director'),
#  (7823, 'Life Sciences', 4, 'Sales', 12, 'Sales Executive'),
#  (7861,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Manufacturing Director'),
#  (7879,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   9,
#   'Healthcare Representative'),
#  (7880, 'Life Sciences', 5, 'Sales', 9, 'Sales Executive'),
#  (7898,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   11,
#   'Manufacturing Director'),
#  (7945,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   18,
#   'Manufacturing Director'),
#  (7991, 'Life Sciences', 2, 'Sales', 6, 'Sales Executive'),
#  (8008,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   9,
#   'Healthcare Representative'),
#  (8189, 'Life Sciences', 1, 'Sales', 12, 'Sales Executive'),
#  (8321,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   15,
#   'Healthcare Representative'),
#  (8376,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   9,
#   'Manufacturing Director'),
#  (8446, 'Life Sciences', 3, 'Sales', 10, 'Sales Executive'),
#  (8474,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   12,
#   'Manufacturing Director'),
#  (8500,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Healthcare Representative'),
#  (8564, 'Life Sciences', 3, 'Sales', 11, 'Sales Executive'),
#  (8578,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   12,
#   'Manufacturing Director'),
#  (8606,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   11,
#   'Healthcare Representative'),
#  (8620, 'Life Sciences', 3, 'Sales', 10, 'Sales Executive'),
#  (8639, 'Life Sciences', 3, 'Sales', 6, 'Sales Executive'),
#  (8686, 'Life Sciences', 4, 'Sales', 12, 'Sales Executive'),
#  (8726, 'Life Sciences', 3, 'Sales', 9, 'Sales Executive'),
#  (8793,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   9,
#   'Manufacturing Director'),
#  (8823,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   20,
#   'Healthcare Representative'),
#  (8837, 'Life Sciences', 4, 'Human Resources', 9, 'Human Resources'),
#  (8853,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   6,
#   'Healthcare Representative'),
#  (8938, 'Life Sciences', 3, 'Sales', 14, 'Sales Executive'),
#  (8943,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   10,
#   'Manufacturing Director'),
#  (8966, 'Life Sciences', 4, 'Sales', 15, 'Sales Executive'),
#  (9069, 'Life Sciences', 5, 'Sales', 9, 'Sales Executive'),
#  (9362,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   10,
#   'Manufacturing Director'),
#  (9419, 'Life Sciences', 3, 'Sales', 12, 'Sales Executive'),
#  (9439,
#   'Life Sciences',
#   2,
#   'Research & Development',
#   12,
#   'Healthcare Representative'),
#  (9526,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Manufacturing Director'),
#  (9547,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   10,
#   'Manufacturing Director'),
#  (9610, 'Life Sciences', 3, 'Sales', 10, 'Sales Executive'),
#  (9679,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   8,
#   'Manufacturing Director'),
#  (9713, 'Life Sciences', 3, 'Sales', 9, 'Sales Executive'),
#  (9714, 'Life Sciences', 3, 'Sales', 10, 'Sales Executive'),
#  (9724,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   25,
#   'Research Scientist'),
#  (9756, 'Life Sciences', 3, 'Human Resources', 9, 'Human Resources'),
#  (9824,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   12,
#   'Healthcare Representative'),
#  (9852, 'Life Sciences', 4, 'Sales', 10, 'Sales Executive'),
#  (9924, 'Life Sciences', 3, 'Sales', 10, 'Sales Executive'),
#  (9980,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   10,
#   'Manufacturing Director'),
#  (9981, 'Life Sciences', 3, 'Sales', 7, 'Sales Executive'),
#  (9985,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   10,
#   'Healthcare Representative'),
#  (9998, 'Life Sciences', 1, 'Sales', 8, 'Sales Executive'),
#  (10124,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   24,
#   'Healthcare Representative'),
#  (10239, 'Life Sciences', 2, 'Sales', 24, 'Sales Executive'),
#  (10274,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   15,
#   'Manufacturing Director'),
#  (10325, 'Life Sciences', 1, 'Sales', 16, 'Sales Executive'),
#  (10333,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   28,
#   'Manufacturing Director'),
#  (10368, 'Life Sciences', 3, 'Sales', 13, 'Sales Executive'),
#  (10435,
#   'Life Sciences',
#   3,
#   'Research & Development',
#   18,
#   'Manufacturing Director'),
#  (10445,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   18,
#   'Healthcare Representative'),
#  (10448, 'Life Sciences', 4, 'Sales', 15, 'Sales Executive'),
#  (10466,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   29,
#   'Healthcare Representative'),
#  (10475, 'Life Sciences', 4, 'Sales', 20, 'Sales Executive'),
#  (10502,
#   'Life Sciences',
#   4,
#   'Research & Development',
#   33,
#   'Manufacturing Director'),
#  (10609, 'Life Sciences', 3, 'Sales', 17, 'Sales Executive'),
#  (10609, 'Life Sciences', 4, 'Sales', 17, 'Sales Executive'),
#  (10648,
#   'Life Sciences',
#   1,
#   'Research & Development',
#   13,
#   'Manufacturing Director'),
#  (10650,
# ...
#  (13695, 'Marketing', 4, 'Sales', 24, 'Sales Executive'),
#  (14118, 'Marketing', 3, 'Sales', 32, 'Manager'),
#  (16064, 'Marketing', 3, 'Sales', 22, 'Manager'),
#  (16307, 'Marketing', 4, 'Sales', 29, 'Manager'),
#  (16856, 'Marketing', 4, 'Sales', 34, 'Manager'),
#  (17048, 'Marketing', 3, 'Sales', 28, 'Manager'),
#  (17465, 'Marketing', 1, 'Sales', 23, 'Manager'),
#  (18213, 'Marketing', 3, 'Sales', 26, 'Manager'),
#  (18303, 'Marketing', 2, 'Sales', 21, 'Manager'),
#  (18789, 'Marketing', 2, 'Sales', 26, 'Manager'),
#  (18824, 'Marketing', 3, 'Sales', 26, 'Manager'),
#  (18947, 'Marketing', 4, 'Sales', 22, 'Manager'),
#  (19331, 'Marketing', 3, 'Sales', 27, 'Manager'),
#  (19586, 'Marketing', 5, 'Sales', 36, 'Manager'),
#  (19845, 'Marketing', 1, 'Sales', 33, 'Manager'),
#  (1009, 'Medical', 1, 'Research & Development', 1, 'Research Scientist'),
#  (1052, 'Medical', 1, 'Sales', 1, 'Sales Representative'),
#  (1081, 'Medical', 3, 'Sales', 1, 'Sales Representative'),
#  (1129, 'Medical', 1, 'Research & Development', 1, 'Laboratory Technician'),
#  (1200, 'Medical', 3, 'Sales', 0, 'Sales Representative'),
#  (1483, 'Medical', 1, 'Research & Development', 1, 'Laboratory Technician'),
#  (1514, 'Medical', 3, 'Research & Development', 0, 'Research Scientist'),
#  (1569, 'Medical', 2, 'Sales', 0, 'Sales Representative'),
#  (1706, 'Medical', 3, 'Research & Development', 0, 'Research Scientist'),
#  (1859, 'Medical', 3, 'Research & Development', 1, 'Research Scientist'),
#  (1904, 'Medical', 1, 'Research & Development', 0, 'Laboratory Technician'),
#  (2001, 'Medical', 4, 'Research & Development', 20, 'Research Scientist'),
#  (2007, 'Medical', 1, 'Research & Development', 5, 'Research Scientist'),
#  (2008, 'Medical', 2, 'Research & Development', 1, 'Laboratory Technician'),
#  (2024, 'Medical', 3, 'Research & Development', 6, 'Research Scientist'),
#  (2028, 'Medical', 3, 'Research & Development', 14, 'Laboratory Technician'),
#  (2042, 'Medical', 3, 'Research & Development', 17, 'Laboratory Technician'),
#  (2044, 'Medical', 3, 'Sales', 2, 'Sales Representative'),
#  (2045, 'Medical', 4, 'Research & Development', 5, 'Research Scientist'),
#  (2070, 'Medical', 3, 'Research & Development', 5, 'Research Scientist'),
#  (2083, 'Medical', 3, 'Research & Development', 1, 'Research Scientist'),
#  (2088, 'Medical', 2, 'Research & Development', 13, 'Laboratory Technician'),
#  (2089, 'Medical', 3, 'Research & Development', 7, 'Research Scientist'),
#  (2096, 'Medical', 1, 'Sales', 7, 'Sales Representative'),
#  (2096, 'Medical', 3, 'Research & Development', 2, 'Research Scientist'),
#  (2109, 'Medical', 2, 'Human Resources', 8, 'Human Resources'),
#  (2127, 'Medical', 5, 'Research & Development', 7, 'Research Scientist'),
#  (2133, 'Medical', 3, 'Research & Development', 20, 'Research Scientist'),
#  (2141, 'Medical', 3, 'Research & Development', 6, 'Research Scientist'),
#  (2144, 'Medical', 3, 'Research & Development', 5, 'Research Scientist'),
#  (2145, 'Medical', 3, 'Human Resources', 3, 'Human Resources'),
#  (2148, 'Medical', 2, 'Human Resources', 6, 'Human Resources'),
#  (2153, 'Medical', 1, 'Research & Development', 8, 'Laboratory Technician'),
#  (2154, 'Medical', 4, 'Research & Development', 5, 'Laboratory Technician'),
#  (2177, 'Medical', 4, 'Human Resources', 6, 'Human Resources'),
#  (2187, 'Medical', 4, 'Research & Development', 6, 'Research Scientist'),
#  (2194, 'Medical', 3, 'Research & Development', 5, 'Research Scientist'),
#  (2206, 'Medical', 2, 'Research & Development', 10, 'Laboratory Technician'),
#  (2232, 'Medical', 4, 'Research & Development', 7, 'Laboratory Technician'),
#  (2244, 'Medical', 3, 'Research & Development', 2, 'Research Scientist'),
#  (2258, 'Medical', 3, 'Research & Development', 8, 'Laboratory Technician'),
#  (2258, 'Medical', 4, 'Research & Development', 10, 'Laboratory Technician'),
#  (2259, 'Medical', 4, 'Research & Development', 13, 'Research Scientist'),
#  (2267, 'Medical', 2, 'Human Resources', 7, 'Human Resources'),
#  (2269, 'Medical', 4, 'Sales', 3, 'Sales Representative'),
#  (2270, 'Medical', 4, 'Research & Development', 8, 'Laboratory Technician'),
#  (2279, 'Medical', 3, 'Research & Development', 7, 'Research Scientist'),
#  (2293, 'Medical', 3, 'Research & Development', 6, 'Research Scientist'),
#  (2305, 'Medical', 4, 'Research & Development', 3, 'Laboratory Technician'),
#  (2311, 'Medical', 2, 'Research & Development', 9, 'Research Scientist'),
#  (2313, 'Medical', 3, 'Research & Development', 5, 'Research Scientist'),
#  (2321, 'Medical', 2, 'Research & Development', 4, 'Research Scientist'),
#  (2323, 'Medical', 1, 'Research & Development', 2, 'Research Scientist'),
#  (2326, 'Medical', 3, 'Research & Development', 4, 'Research Scientist'),
#  (2342, 'Medical', 1, 'Research & Development', 5, 'Research Scientist'),
#  (2342, 'Medical', 2, 'Research & Development', 6, 'Research Scientist'),
#  (2345, 'Medical', 3, 'Research & Development', 8, 'Research Scientist'),
#  (2366, 'Medical', 2, 'Research & Development', 8, 'Research Scientist'),
#  (2370, 'Medical', 3, 'Research & Development', 8, 'Laboratory Technician'),
#  (2372, 'Medical', 4, 'Research & Development', 18, 'Research Scientist'),
#  (2373, 'Medical', 4, 'Research & Development', 5, 'Laboratory Technician'),
#  (2377, 'Medical', 3, 'Research & Development', 1, 'Laboratory Technician'),
#  (2377, 'Medical', 3, 'Research & Development', 6, 'Research Scientist'),
#  (2380, 'Medical', 1, 'Sales', 2, 'Sales Representative'),
#  (2389, 'Medical', 1, 'Research & Development', 4, 'Research Scientist'),
#  (2398, 'Medical', 1, 'Research & Development', 1, 'Laboratory Technician'),
#  (2400, 'Medical', 3, 'Sales', 3, 'Sales Representative'),
#  (2404, 'Medical', 3, 'Research & Development', 8, 'Laboratory Technician'),
#  (2408, 'Medical', 3, 'Research & Development', 1, 'Laboratory Technician'),
#  (2422, 'Medical', 3, 'Research & Development', 4, 'Laboratory Technician'),
#  (2426, 'Medical', 3, 'Research & Development', 6, 'Laboratory Technician'),
#  (2436, 'Medical', 3, 'Research & Development', 6, 'Research Scientist'),
#  (2436, 'Medical', 3, 'Research & Development', 8, 'Laboratory Technician'),
#  (2440, 'Medical', 3, 'Research & Development', 4, 'Laboratory Technician'),
#  (2450, 'Medical', 3, 'Research & Development', 3, 'Laboratory Technician'),
#  (2468, 'Medical', 2, 'Research & Development', 9, 'Laboratory Technician'),
#  (2496, 'Medical', 3, 'Research & Development', 7, 'Laboratory Technician'),
#  (2500, 'Medical', 1, 'Research & Development', 5, 'Laboratory Technician'),
#  (2501, 'Medical', 4, 'Research & Development', 1, 'Research Scientist'),
#  (2515, 'Medical', 1, 'Research & Development', 8, 'Research Scientist'),
#  (2519, 'Medical', 4, 'Research & Development', 16, 'Laboratory Technician'),
#  (2532, 'Medical', 1, 'Research & Development', 8, 'Laboratory Technician'),
#  (2534, 'Medical', 3, 'Sales', 5, 'Sales Representative'),
#  (2559, 'Medical', 1, 'Research & Development', 6, 'Research Scientist'),
#  (2561, 'Medical', 2, 'Research & Development', 8, 'Laboratory Technician'),
#  (2564, 'Medical', 3, 'Research & Development', 12, 'Laboratory Technician'),
#  (2566, 'Medical', 3, 'Research & Development', 1, 'Research Scientist'),
#  (2570, 'Medical', 3, 'Research & Development', 7, 'Laboratory Technician'),
#  (2571, 'Medical', 2, 'Research & Development', 17, 'Laboratory Technician'),
#  (2580, 'Medical', 3, 'Research & Development', 6, 'Research Scientist'),
#  (2587, 'Medical', 3, 'Research & Development', 17, 'Laboratory Technician'),
#  (2593, 'Medical', 3, 'Research & Development', 10, 'Laboratory Technician'),
#  (2596, 'Medical', 3, 'Research & Development', 1, 'Laboratory Technician'),
#  (2600, 'Medical', 3, 'Research & Development', 1, 'Research Scientist'),
#  (2610, 'Medical', 2, 'Sales', 3, 'Sales Representative'),
#  (2610, 'Medical', 3, 'Research & Development', 2, 'Laboratory Technician'),
#  (2622, 'Medical', 4, 'Research & Development', 7, 'Research Scientist'),
#  (2645, 'Medical', 2, 'Research & Development', 6, 'Research Scientist'),
#  (2655, 'Medical', 2, 'Sales', 19, 'Sales Representative'),
#  (2660, 'Medical', 4, 'Research & Development', 5, 'Laboratory Technician'),
#  (2661, 'Medical', 2, 'Research & Development', 3, 'Laboratory Technician'),
#  (2670, 'Medical', 3, 'Research & Development', 12, 'Laboratory Technician'),
#  (2684, 'Medical', 1, 'Research & Development', 3, 'Research Scientist'),
#  (2705, 'Medical', 4, 'Research & Development', 6, 'Laboratory Technician'),
#  (2713, 'Medical', 3, 'Research & Development', 5, 'Research Scientist'),
#  (2720, 'Medical', 1, 'Research & Development', 6, 'Laboratory Technician'),
#  (2725, 'Medical', 3, 'Research & Development', 6, 'Research Scientist'),
#  (2741, 'Medical', 2, 'Research & Development', 15, 'Laboratory Technician'),
#  (2756, 'Medical', 3, 'Research & Development', 8, 'Research Scientist'),
#  (2759, 'Medical', 3, 'Research & Development', 7, 'Research Scientist'),
#  (2766, 'Medical', 3, 'Research & Development', 7, 'Laboratory Technician'),
#  (2773, 'Medical', 1, 'Research & Development', 3, 'Research Scientist'),
#  (2781, 'Medical', 3, 'Research & Development', 15, 'Research Scientist'),
#  (2783, 'Medical', 3, 'Sales', 2, 'Sales Representative'),
#  (2800, 'Medical', 3, 'Sales', 5, 'Sales Representative'),
#  (2804, 'Medical', 1, 'Human Resources', 1, 'Human Resources'),
#  (2819, 'Medical', 3, 'Research & Development', 5, 'Research Scientist'),
#  (2838, 'Medical', 2, 'Research & Development', 8, 'Laboratory Technician'),
#  (2856, 'Medical', 3, 'Sales', 1, 'Sales Representative'),
#  (2859, 'Medical', 3, 'Research & Development', 6, 'Research Scientist'),
#  (2867, 'Medical', 3, 'Research & Development', 8, 'Laboratory Technician'),
#  (2871, 'Medical', 3, 'Research & Development', 1, 'Laboratory Technician'),
#  (2889, 'Medical', 1, 'Research & Development', 2, 'Research Scientist'),
#  (2932, 'Medical', 4, 'Research & Development', 6, 'Research Scientist'),
#  (2935, 'Medical', 2, 'Research & Development', 1, 'Laboratory Technician'),
#  (2942, 'Medical', 3, 'Research & Development', 18, 'Research Scientist'),
#  (2960, 'Medical', 1, 'Research & Development', 8, 'Research Scientist'),
#  (2972, 'Medical', 4, 'Research & Development', 1, 'Research Scientist'),
#  (2973, 'Medical', 2, 'Sales', 10, 'Sales Representative'),
#  (2974, 'Medical', 4, 'Research & Development', 9, 'Laboratory Technician'),
#  (2976, 'Medical', 1, 'Sales', 5, 'Sales Representative'),
#  (3057, 'Medical', 5, 'Research & Development', 6, 'Research Scientist'),
#  (3065, 'Medical', 2, 'Research & Development', 4, 'Research Scientist'),
#  (3069, 'Medical', 2, 'Research & Development', 11, 'Laboratory Technician'),
#  (3072, 'Medical', 3, 'Research & Development', 12, 'Laboratory Technician'),
#  (3117, 'Medical', 1, 'Research & Development', 3, 'Research Scientist'),
#  (3131, 'Medical', 1, 'Research & Development', 10, 'Laboratory Technician'),
#  (3172, 'Medical', 3, 'Research & Development', 4, 'Laboratory Technician'),
#  (3196, 'Medical', 4, 'Research & Development', 6, 'Laboratory Technician'),
#  (3221, 'Medical', 1, 'Research & Development', 20, 'Laboratory Technician'),
#  (3230, 'Medical', 2, 'Research & Development', 3, 'Research Scientist'),
#  (3295, 'Medical', 1, 'Research & Development', 3, 'Laboratory Technician'),
#  (3306, 'Medical', 2, 'Research & Development', 7, 'Laboratory Technician'),
#  (3346, 'Medical', 3, 'Research & Development', 9, 'Research Scientist'),
#  (3388, 'Medical', 3, 'Research & Development', 2, 'Research Scientist'),
#  (3408, 'Medical', 1, 'Research & Development', 8, 'Laboratory Technician'),
#  (3424, 'Medical', 1, 'Research & Development', 6, 'Research Scientist'),
#  (3445, 'Medical', 3, 'Research & Development', 6, 'Research Scientist'),
#  (3448, 'Medical', 3, 'Research & Development', 20, 'Laboratory Technician'),
#  (3452, 'Medical', 3, 'Research & Development', 9, 'Research Scientist'),
#  (3452, 'Medical', 3, 'Research & Development', 17, 'Laboratory Technician'),
#  (3464, 'Medical', 4, 'Research & Development', 5, 'Research Scientist'),
#  (3468, 'Medical', 1, 'Research & Development', 6, 'Laboratory Technician'),
#  (3479, 'Medical', 2, 'Research & Development', 6, 'Laboratory Technician'),
#  (3505, 'Medical', 1, 'Research & Development', 2, 'Research Scientist'),
#  (3517, 'Medical', 3, 'Research & Development', 5, 'Research Scientist'),
#  (3540, 'Medical', 1, 'Sales', 9, 'Sales Representative'),
#  (3579, 'Medical', 3, 'Research & Development', 12, 'Research Scientist'),
#  (3591, 'Medical', 3, 'Research & Development', 3, 'Research Scientist'),
#  (3597, 'Medical', 3, 'Research & Development', 6, 'Laboratory Technician'),
#  (3617, 'Medical', 4, 'Research & Development', 3, 'Research Scientist'),
#  (3629, 'Medical', 3, 'Research & Development', 8, 'Laboratory Technician'),
#  (3669, 'Medical', 1, 'Research & Development', 7, 'Laboratory Technician'),
#  (3673, 'Medical', 2, 'Research & Development', 12, 'Laboratory Technician'),
#  (3690, 'Medical', 3, 'Research & Development', 5, 'Laboratory Technician'),
#  (3708, 'Medical', 3, 'Research & Development', 9, 'Laboratory Technician'),
#  (3748, 'Medical', 2, 'Research & Development', 12, 'Laboratory Technician'),
#  (3785, 'Medical', 4, 'Research & Development', 5, 'Research Scientist'),
#  (3812, 'Medical', 1, 'Research & Development', 11, 'Laboratory Technician'),
#  (3815, 'Medical', 4, 'Research & Development', 5, 'Research Scientist'),
#  (3816, 'Medical', 2, 'Research & Development', 5, 'Laboratory Technician'),
#  (3838, 'Medical', 4, 'Research & Development', 8, 'Laboratory Technician'),
#  (3904, 'Medical', 1, 'Research & Development', 5, 'Research Scientist'),
#  (3904, 'Medical', 3, 'Research & Development', 6, 'Research Scientist'),
#  (3907, 'Medical', 1, 'Research & Development', 6, 'Laboratory Technician'),
#  (3920, 'Medical', 2, 'Research & Development', 17, 'Research Scientist'),
#  (3929, 'Medical', 1, 'Research & Development', 7, 'Research Scientist'),
#  (3936, 'Medical', 3, 'Research & Development', 8, 'Research Scientist'),
#  (3955, 'Medical', 2, 'Research & Development', 6, 'Laboratory Technician'),
#  (3978, 'Medical', 3, 'Research & Development', 4, 'Laboratory Technician'),
#  (3986, 'Medical', 2, 'Research & Development', 15, 'Laboratory Technician'),
#  (3989, 'Medical', 1, 'Research & Development', 5, 'Laboratory Technician'),
#  (4011, 'Medical', 2, 'Research & Development', 12, 'Laboratory Technician'),
#  (4014, 'Medical', 4, 'Research & Development', 4, 'Laboratory Technician'),
#  (4025, 'Medical', 4, 'Research & Development', 10, 'Laboratory Technician'),
#  (4031, 'Medical', 3, 'Research & Development', 6, 'Laboratory Technician'),
#  (4037, 'Medical', 3, 'Sales', 9, 'Sales Executive'),
#  (4081, 'Medical', 3, 'Research & Development', 20, 'Research Scientist'),
#  (4162, 'Medical', 1, 'Sales', 5, 'Sales Executive'),
#  (4187, 'Medical', 3, 'Sales', 10, 'Sales Executive'),
#  (4200, 'Medical', 3, 'Research & Development', 10, 'Laboratory Technician'),
#  (4213, 'Medical', 4, 'Research & Development', 10, 'Manufacturing Director'),
#  (4221, 'Medical', 3, 'Sales', 5, 'Sales Executive'),
#  (4233, 'Medical', 4, 'Sales', 9, 'Sales Executive'),
#  (4244,
#   'Medical',
#   2,
#   'Research & Development',
#   8,
#   'Healthcare Representative'),
#  (4258, 'Medical', 4, 'Research & Development', 5, 'Research Scientist'),
#  (4272, 'Medical', 3, 'Research & Development', 16, 'Laboratory Technician'),
#  (4284, 'Medical', 4, 'Research & Development', 16, 'Research Scientist'),
#  (4285, 'Medical', 3, 'Research & Development', 10, 'Research Scientist'),
#  (4294, 'Medical', 3, 'Sales', 7, 'Sales Executive'),
#  (4306, 'Medical', 2, 'Research & Development', 13, 'Manufacturing Director'),
#  (4306, 'Medical', 2, 'Sales', 8, 'Sales Executive'),
#  (4325, 'Medical', 2, 'Research & Development', 5, 'Manufacturing Director'),
#  (4327, 'Medical', 4, 'Sales', 5, 'Sales Executive'),
#  (4335,
#   'Medical',
#   3,
#   'Research & Development',
#   11,
#   'Healthcare Representative'),
#  (4345, 'Medical', 4, 'Research & Development', 6, 'Manufacturing Director'),
#  (4373, 'Medical', 3, 'Sales', 5, 'Sales Executive'),
#  (4374, 'Medical', 4, 'Research & Development', 4, 'Manufacturing Director'),
#  ...]

# %%
def depart_job_range(data, min_value, max_value):
    all_found = []
    for element in data:
        if str(max_value) == 'no max':
            max_value = 2147483647
        if element[0] >= int(min_value) and element[0] < int(max_value):
            add_to_all_found = True
            for element2 in all_found:
                for key, value in element2.items():
                    klucz = key
                    wartosc = value
                if klucz == element[3] and wartosc == element[5]:
                    add_to_all_found = False
                    break
            if add_to_all_found:
                #print(str(element[1]) + ' ' + element[2])
                #printed.update({element[1]: element[2]})
                all_found.append({element[3]: element[5]}) 
    return all_found
print (depart_job_range(total_list_sorted,5000,7000))
# Out:
# [{'Human Resources': 'Human Resources'}, {'Research & Development': 'Research Scientist'}, {'Sales': 'Sales Executive'}, {'Research & Development': 'Healthcare Representative'}, {'Research & Development': 'Manufacturing Director'}, {'Research & Development': 'Laboratory Technician'}, {'Sales': 'Sales Representative'}]

# %%
def educationfield(data, min_value, max_value):
    all_found = []
    for element in total_list:
        if str(max_value) == 'no max':
            max_value = 2147483647
        if element[0] >= int(min_value) and element[0] < int(max_value):
            add_to_all_found = True
            for element2 in all_found:
                for key, value in element2.items():
                    klucz = key
                    wartosc = value
                if klucz == element[1] and wartosc == element[5]:
                    add_to_all_found = False
                    break
            if add_to_all_found:
                 all_found.append({element[1]: element[5]}) 
    return all_found
print(educationfield(total_list, 19000, 21000))
