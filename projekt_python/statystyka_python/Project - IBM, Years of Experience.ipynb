# %%
# imports

import pandas as pd
import matplotlib.pyplot as plt

# %%
bottom = 5000
upper = 7000
experience_yrs = 14

path_to_file = 'C:/Users/48510/OneDrive/Pulpit/IBMdata.csv'
all_data = pd.read_csv(path_to_file)

# %%
all_data = all_data[(data['MonthlyIncome'] > bottom) & (data['MonthlyIncome'] < upper)]

# %%
all_data.head()
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 27   42        No      Travel_Rarely        691                   Sales
# 31   44        No      Travel_Rarely       1459  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                  1          2  Life Sciences              1               1
# 1                  8          1  Life Sciences              1               2
# 9                 27          3        Medical              1              13
# 27                 8          4      Marketing              1              35
# 31                10          4          Other              1              40
#
#     ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0   ...                         1            80                 0
# 1   ...                         4            80                 1
# 9   ...                         2            80                 2
# 27  ...                         4            80                 1
# 31  ...                         4            80                 0
#
#     TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                   8                      0               1               6
# 1                  10                      3               3              10
# 9                  17                      3               2               7
# 27                 10                      2               3               9
# 31                  9                      5               4               4
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 9                   7                        7                     7
# 27                  7                        4                     2
# 31                  2                        1                     3
#
# [5 rows x 35 columns]

# %%
all_data.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1453   36        No      Travel_Rarely       1120                   Sales
# 1456   35        No  Travel_Frequently       1199  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1452                 1          4  Life Sciences              1
# 1453                11          4      Marketing              1
# 1456                18          4  Life Sciences              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 1452            2044  ...                         4            80
# 1453            2045  ...                         1            80
# 1456            2049  ...                         4            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1452                 2                 12                      3
# 1453                 1                  8                      2
# 1456                 2                 10                      2
# 1467                 1                  6                      0
# 1468                 0                 17                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 1452               3               6                  3
# 1453               2               6                  3
# 1456               4              10                  2
# 1467               3               6                  2
# 1468               2               9                  6
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 1452                        0                     1
# 1453                        0                     0
# 1456                        0                     2
# 1467                        0                     3
# 1468                        0                     8
#
# [5 rows x 35 columns]

# %%
print(list(all_data.columns))
# Out:
# ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
df = all_data[['TotalWorkingYears', 'Department', 'JobRole']]  # extracting 3 columns

# %%
df
# Out:
#       TotalWorkingYears              Department                    JobRole
# 0                     8                   Sales            Sales Executive
# 1                    10  Research & Development         Research Scientist
# 9                    17  Research & Development  Healthcare Representative
# 27                   10                   Sales            Sales Executive
# 31                    9  Research & Development  Healthcare Representative
# ...                 ...                     ...                        ...
# 1452                 12                   Sales            Sales Executive
# 1453                  8                   Sales            Sales Executive
# 1456                 10  Research & Development  Healthcare Representative
# 1467                  6  Research & Development     Manufacturing Director
# 1468                 17                   Sales            Sales Executive
#
# [286 rows x 3 columns]

# %%
# histogram of total working years

plt.hist(df['TotalWorkingYears'])
plt.show()

# %%
grp_min = df.groupby(['JobRole']).min()
grp_min = grp_min.reset_index()
print(grp_min)
# Out:
#                      JobRole  TotalWorkingYears              Department
# 0  Healthcare Representative                  6  Research & Development
# 1            Human Resources                  9         Human Resources
# 2      Laboratory Technician                  9  Research & Development
# 3     Manufacturing Director                  6  Research & Development
# 4         Research Scientist                  6  Research & Development
# 5            Sales Executive                  4                   Sales
# 6       Sales Representative                  9                   Sales

# %%
grp_max = df.groupby(['JobRole']).max()
grp_max = grp_max.reset_index()
print(grp_max)
# Out:
#                      JobRole  TotalWorkingYears              Department
# 0  Healthcare Representative                 20  Research & Development
# 1            Human Resources                 16         Human Resources
# 2      Laboratory Technician                 24  Research & Development
# 3     Manufacturing Director                 20  Research & Development
# 4         Research Scientist                 20  Research & Development
# 5            Sales Executive                 20                   Sales
# 6       Sales Representative                 20                   Sales

# %%
df_ranges = pd.DataFrame()

df_ranges['JobRole'] = grp_min['JobRole']
df_ranges['Min'] = grp_min['TotalWorkingYears']
df_ranges['Max'] = grp_max['TotalWorkingYears']

# %%
df_ranges
# Out:
#                      JobRole  Min  Max
# 0  Healthcare Representative    6   20
# 1            Human Resources    9   16
# 2      Laboratory Technician    9   24
# 3     Manufacturing Director    6   20
# 4         Research Scientist    6   20
# 5            Sales Executive    4   20
# 6       Sales Representative    9   20

# %%
adequate_roles = []

for index, row in df_ranges.iterrows():
    
    lower = row['Min']
    upper = row['Max']
    role = row['JobRole']
    
    if lower <= experience_yrs <= upper:
        
        adequate_roles.append(role)

# %%
adequate_roles
# Out:
# ['Healthcare Representative',
#  'Human Resources',
#  'Laboratory Technician',
#  'Manufacturing Director',
#  'Research Scientist',
#  'Sales Executive',
#  'Sales Representative']
