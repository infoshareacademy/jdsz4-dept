# %%
import pandas as pd
import os
import numpy as np
from matplotlib import pyplot

# %%
file_path = "/home/t/ds/projekt_grupowy_who_am_i/WA_Fn-UseC_-HR-Employee-Attrition.csv"

# %%
df= pd.read_csv(file_path)

# %%
df_copy = df.copy()

# %%
df_copy
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
total_base = df_copy[['MonthlyIncome', 'EducationField', 'Education', 'TotalWorkingYears', 'Department', 'JobRole']]

# %%
total_base
# Out:
#       MonthlyIncome EducationField  Education  TotalWorkingYears  \
# 0              5993  Life Sciences          2                  8
# 1              5130  Life Sciences          1                 10
# 2              2090          Other          2                  7
# 3              2909  Life Sciences          4                  8
# 4              3468        Medical          1                  6
# ...             ...            ...        ...                ...
# 1465           2571        Medical          2                 17
# 1466           9991        Medical          1                  9
# 1467           6142  Life Sciences          3                  6
# 1468           5390        Medical          3                 17
# 1469           4404        Medical          3                  6
#
#                   Department                    JobRole
# 0                      Sales            Sales Executive
# 1     Research & Development         Research Scientist
# ...

# %%
# if total_base[total_base['MonthlyIncome'] > 5000]:
#     print (total_base['MonthlyIncome'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-4ffe0bc2c4b4> in <module>
# ----> 1 if total_base[total_base['MonthlyIncome'] > 5000]:
#       2     print (total_base['MonthlyIncome'])
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
data = [1, 2, 3, 2, 2, 6, 7]
seria = pd.Series(data)
ramka = pd.DataFrame()
ramka["kolumna_1"] = seria
my_filtered_df = ramka[ramka["kolumna_1"] >= 3]
print(my_filtered_df)
nowa_ramka = pd.DataFrame(my_filtered_df.reset_index(drop=True))
print(nowa_ramka)
# Out:
#    kolumna_1
# 2          3
# 5          6
# 6          7
#    kolumna_1
# 0          3
# 1          6
# 2          7

# %%
total_base["MonthlyIncome"]
# Out:
# 0       5993
# 1       5130
# 2       2090
# 3       2909
# 4       3468
#         ...
# 1465    2571
# 1466    9991
# 1467    6142
# 1468    5390
# 1469    4404
# Name: MonthlyIncome, Length: 1470, dtype: int64

# %%
mi_filtred_df = total_base[(total_base["MonthlyIncome"] >= 3001) & (total_base["MonthlyIncome"] <= 5000)]
print(mi_filtred_df)
# Out:
#       MonthlyIncome EducationField  Education  TotalWorkingYears  \
# 4              3468        Medical          1                  6
# 5              3068  Life Sciences          2                  8
# 11             4193  Life Sciences          2                 10
# 16             3298  Life Sciences          2                  7
# 19             3944  Life Sciences          3                  6
# ...             ...            ...        ...                ...
# 1442           4787        Medical          4                  4
# 1454           4850  Life Sciences          3                  8
# 1459           4025          Other          2                 10
# 1460           3785        Medical          4                  5
# 1469           4404        Medical          3                  6
#
#                   Department                JobRole
# 4     Research & Development  Laboratory Technician
# 5     Research & Development  Laboratory Technician
# ...

# %%
def depart_job_range(data, min_value, max_value):
    for element in data:
        if max_value == 'no max':
            max_value = 2147483647
        if mi_filtred_df = total_base[(total_base["MonthlyIncome"] >= int(min_value)) & (total_base["MonthlyIncome"] <= int(max_value))]
            return mi_filtred_df

# %%
def depart_job_range(data, min_value, max_value):
    for element in data:
        if max_value == 'no max':
            max_value = 2147483647
        if total_base.iloc[(total_base[0] >= int(min_value)) & (total_base[1] <= int(max_value))]:
    return mi_filtred_df

# %%
def depart_job(data, mi, ma):
    if ((data["MonthlyIncome"] >= mi) & (data["MonthlyIncome"] <= ma)).any():
        mi_filtred_df = data[(data["MonthlyIncome"] >= mi) & (data["MonthlyIncome"] <= ma)]
        return mi_filtred_df

# %%
#toototototot
def depart_job(data, mi, ma):
    if ma == 'no max':
            ma = 2147483647
    if ((data["MonthlyIncome"] >= mi) & (data["MonthlyIncome"] <= ma)).any():
        mi_filtred_df1 = data[(data["MonthlyIncome"] >= mi) & (data["MonthlyIncome"] <= ma)]
        return mi_filtred_df1

# %%
depart_job(total_base, 3001, 5000)
# Out:
#       MonthlyIncome EducationField  Education  TotalWorkingYears  \
# 4              3468        Medical          1                  6
# 5              3068  Life Sciences          2                  8
# 11             4193  Life Sciences          2                 10
# 16             3298  Life Sciences          2                  7
# 19             3944  Life Sciences          3                  6
# ...             ...            ...        ...                ...
# 1442           4787        Medical          4                  4
# 1454           4850  Life Sciences          3                  8
# 1459           4025          Other          2                 10
# 1460           3785        Medical          4                  5
# 1469           4404        Medical          3                  6
#
#                   Department                JobRole
# 4     Research & Development  Laboratory Technician
# 5     Research & Development  Laboratory Technician
# ...

# %%
mi_filtred_df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-95655b836690> in <module>
# ----> 1 mi_filtred_df1
#
# NameError: name 'mi_filtred_df1' is not defined

# %%
test2 = total_base[(total_base["TotalWorkingYears"] >= 0) & (total_base["TotalWorkingYears"] <= 10)]
test2 # tutaj testuje, ale dzialanie jakby jednego filtra
# Out:
#       MonthlyIncome EducationField  Education  TotalWorkingYears  \
# 0              5993  Life Sciences          2                  8
# 1              5130  Life Sciences          1                 10
# 2              2090          Other          2                  7
# 3              2909  Life Sciences          4                  8
# 4              3468        Medical          1                  6
# ...             ...            ...        ...                ...
# 1463           9936        Medical          3                 10
# 1464           2966          Other          3                  5
# 1466           9991        Medical          1                  9
# 1467           6142  Life Sciences          3                  6
# 1469           4404        Medical          3                  6
#
#                   Department                    JobRole
# 0                      Sales            Sales Executive
# 1     Research & Development         Research Scientist
# ...

# %%
def total_w_y(data, mi, ma):
    if ((data["TotalWorkingYears"] >= mi) & (data["TotalWorkingYears"] <= ma)).any():
        #tw_filtred_df = data[(data["MonthlyIncome"] >= mi) & (data["MonthlyIncome"] <= ma)]
        tw_filtred_df2 = data[(data["TotalWorkingYears"] >= mi) & (data["TotalWorkingYears"] <= ma)]
        return tw_filtred_df2

# %%
total_w_y(total_base,0, 10)
# Out:
#       MonthlyIncome EducationField  Education  TotalWorkingYears  \
# 0              5993  Life Sciences          2                  8
# 1              5130  Life Sciences          1                 10
# 2              2090          Other          2                  7
# 3              2909  Life Sciences          4                  8
# 4              3468        Medical          1                  6
# ...             ...            ...        ...                ...
# 1463           9936        Medical          3                 10
# 1464           2966          Other          3                  5
# 1466           9991        Medical          1                  9
# 1467           6142  Life Sciences          3                  6
# 1469           4404        Medical          3                  6
#
#                   Department                    JobRole
# 0                      Sales            Sales Executive
# 1     Research & Development         Research Scientist
# ...

# %%
test3 = total_base[(total_base["EducationField"] == "Life Sciences")]
test3
# Out:
#       MonthlyIncome EducationField  Education  TotalWorkingYears  \
# 0              5993  Life Sciences          2                  8
# 1              5130  Life Sciences          1                 10
# 3              2909  Life Sciences          4                  8
# 5              3068  Life Sciences          2                  8
# 7              2693  Life Sciences          1                  1
# ...             ...            ...        ...                ...
# 1454           4850  Life Sciences          3                  8
# 1455           2809  Life Sciences          4                  8
# 1456           5689  Life Sciences          4                 10
# 1458           2977  Life Sciences          4                  4
# 1467           6142  Life Sciences          3                  6
#
#                   Department                    JobRole
# 0                      Sales            Sales Executive
# 1     Research & Development         Research Scientist
# ...

# %%
def edu_field(data, edu_f):
    if (data["EducationField"] == edu_f).any():
        #tw_filtred_df = data[(data["MonthlyIncome"] >= mi) & (data["MonthlyIncome"] <= ma)]
        ef_filtred_df3 = data[(data["EducationField"] == edu_f)]
        return ef_filtred_df3

# %%
edu_field(total_base, "Life Sciences")
# Out:
#       MonthlyIncome EducationField  Education  TotalWorkingYears  \
# 0              5993  Life Sciences          2                  8
# 1              5130  Life Sciences          1                 10
# 3              2909  Life Sciences          4                  8
# 5              3068  Life Sciences          2                  8
# 7              2693  Life Sciences          1                  1
# ...             ...            ...        ...                ...
# 1454           4850  Life Sciences          3                  8
# 1455           2809  Life Sciences          4                  8
# 1456           5689  Life Sciences          4                 10
# 1458           2977  Life Sciences          4                  4
# 1467           6142  Life Sciences          3                  6
#
#                   Department                    JobRole
# 0                      Sales            Sales Executive
# 1     Research & Development         Research Scientist
# ...

# %%
test4 = total_base[(total_base["Education"] == 1)]
test4
# Out:
#       MonthlyIncome EducationField  Education  TotalWorkingYears  \
# 1              5130  Life Sciences          1                 10
# 4              3468        Medical          1                  6
# 7              2693  Life Sciences          1                  1
# 12             2911  Life Sciences          1                  5
# 24             2960        Medical          1                  8
# ...             ...            ...        ...                ...
# 1421          11957        Medical          1                 14
# 1429           4108  Life Sciences          1                 18
# 1436           2380        Medical          1                  2
# 1462          12031      Marketing          1                 21
# 1466           9991        Medical          1                  9
#
#                   Department                    JobRole
# 1     Research & Development         Research Scientist
# 4     Research & Development      Laboratory Technician
# ...

# %%
def edu_lvl(data, edu_l):
    if (data["Education"] == edu_l).any():
        #tw_filtred_df = data[(data["MonthlyIncome"] >= mi) & (data["MonthlyIncome"] <= ma)]
        el_filtred_df4 = data[(data["Education"] == edu_l)]
        return el_filtred_df4

# %%
edu_lvl(total_base, 1)
# Out:
#       MonthlyIncome EducationField  Education  TotalWorkingYears  \
# 1              5130  Life Sciences          1                 10
# 4              3468        Medical          1                  6
# 7              2693  Life Sciences          1                  1
# 12             2911  Life Sciences          1                  5
# 24             2960        Medical          1                  8
# ...             ...            ...        ...                ...
# 1421          11957        Medical          1                 14
# 1429           4108  Life Sciences          1                 18
# 1436           2380        Medical          1                  2
# 1462          12031      Marketing          1                 21
# 1466           9991        Medical          1                  9
#
#                   Department                    JobRole
# 1     Research & Development         Research Scientist
# 4     Research & Development      Laboratory Technician
# ...

# %%
def get_income_limits(user_monthlyIncome):
    limits = [
        (1000, 3000),
        (3000, 5000),
        (5000, 7000),
        (7000, 9000),
        (9000, 11000),
        (11000, 13000),
        (13000, 15000),
        (15000, 17000),
        (17000,20000)
    ]
    for min_val, max_val in limits:
        if min_val < user_monthlyIncome <= max_val:
            return min_val, max_val
user_monthlyIncome = int(input('Jakie są Twoje wymarzone zarobki?:'))
monthlyincome_min_limit, monthlyincome_max_limit = get_income_limits(user_monthlyIncome)
print(monthlyincome_min_limit, monthlyincome_max_limit)
filtr_1 = (total_base['MonthlyIncome'] > monthlyincome_min_limit) & (total_base['MonthlyIncome'] < monthlyincome_max_limit)
df_1_filtr = total_base[filtr_1]
print(df_1_filtr)

# %%
poziomy = ['Below College', 'College', 'Bachelor', 'Master', 'Doctor']

# %%
poziomy2 = ['Human Resources', 'Life Sciences', 'Technical Degree', 'Medical', 'MarketingOther']

# %%
value1 = int(input('Jakie są Twoje wymarzone zarobki?:'))
# print("")
# print(poziomy)
print("")
value2 = int(input('Podaj lata swojego doświadczenia: '))
print("")
print(poziomy2)
value3 = str(input('Wybierz z listy nie wiem jak to nazwac, dziura w mozgu: '))
print("")
print(poziomy)
value4 = str(input('Korzystajac z listy, wybierz swoj poziom wyksztalcenia: '))

print('Oto propozycje stanowisk dla Ciebie:')

if value1 >= 11001:
    wyniki = depart_job(total_base, 11001, "no max")
    print(wyniki)
    
elif value1 >=9001 and value1 < 11000:
    wyniki = depart_job(total_base, 9001, 11000)
    print(wyniki)
    
elif value1 >= 5001 and value1 < 9000:
    wyniki = depart_job(total_base, 5001, 9000)
    print(wyniki)
    
elif value1 >= 3001 and value1 < 5000:
    wyniki = depart_job(total_base, 3001, 5000)
    print(wyniki)
    
elif value1 < 3000:
    wyniki = depart_job(total_base, 0, 3000)
    print(wyniki)
# else:
#     print('nic')
    
if value2 >= 0 and value2 < 1:
    wyniki2 = total_w_y(wyniki, 0, 1)
    print(wyniki2)
    
elif value2 >= 1 and value2 < 2:
    wyniki2 = total_w_y(wyniki, 0, 2)
    print(wyniki2)

elif value2 >= 2 and value2 < 3:
    wyniki2 = total_w_y(wyniki, 0, 3)
    print(wyniki2)
    
elif value2 >= 4 and value2 < 6:
    wyniki2 = total_w_y(wyniki, 0, 6)
    print(wyniki2)

elif value2 >= 6 and value2 < 10:
    wyniki2 = total_w_y(wyniki, 0, 10)
    print(wyniki2)

elif value2 >= 10 and value2 < 20:
    wyniki2 = total_w_y(wyniki, 0, 20)
    print(wyniki2)    

elif value2 >= 21 and value2 < 30:
    wyniki2 = total_w_y(wyniki, 0, 30)
    print(wyniki2) 
    
elif value2 >= 30 and value2 < 40:
    wyniki2 = total_w_y(wyniki, 0, 40)
    print(wyniki2)
# print(wyniki)

if value3 == "Life Sciences":
    wyniki3 = edu_field(wyniki2, "Life Sciences")
    print(wyniki3)

elif value3 == "Human Resources":
    wyniki3 = edu_field(wyniki2, "Human Resources")
    print(wyniki3)
    
elif value3 == "Technical Degree":
    wyniki3 = edu_field(wyniki2, "Technical Degree")
    print(wyniki3)
    
elif value3 == "Medical":
    wyniki3 = edu_field(wyniki2, "Medical")
    print(wyniki3)
    
elif value3 == "Marketing":
    wyniki3 = edu_field(wyniki2, "Marketing")
    print(wyniki3)
    
elif value3 == "Other":
    wyniki3 = edu_field(wyniki2, "Other")
    print(wyniki3)

if value4 == "Below College":
    wyniki4 = edu_lvl(wyniki3, 1)
    print(wyniki4)
    
elif value4 == "College":
    wyniki4 = edu_lvl(wyniki3, 2)
    print(wyniki4)
    
elif value4 == "Bachelor":
    wyniki4 = edu_lvl(wyniki3, 3)
    uniqueValues = (wyniki4['JobRole'].unique())
    uniqueValues = (wyniki4['Department'].append(wyniki4['JobRole'])).unique()
    print(uniqueValues)
#     print('Departament: ' + wyniki4['Department']  + '   Stanowisko: ' + uniqueValues)
#     wydruk = (wyniki4.groupby(['JobRole']))
#     print(wydruk)

elif value4 == "Master":
    wyniki4 = edu_lvl(wyniki3, 4)
    print(wyniki4)
    
elif value4 == "Doctor":
    wyniki4 = edu_lvl(wyniki3, 5)
    print(wyniki4)
#     print(wyniki4['JobRole'].unique())
# print(wyniki3)
# Out:
# Jakie są Twoje wymarzone zarobki?:4000
#
# Podaj lata swojego doświadczenia: 5
#
# ['Human Resources', 'Life Sciences', 'Technical Degree', 'Medical', 'MarketingOther']
# Wybierz z listy nie wiem jak to nazwac, dziura w mozgu: Life Sciences
#
# ['Below College', 'College', 'Bachelor', 'Master', 'Doctor']
# Korzystajac z listy, wybierz swoj poziom wyksztalcenia: Bachelor
# Oto propozycje stanowisk dla Ciebie:
#       MonthlyIncome EducationField  Education  TotalWorkingYears  \
# 4              3468        Medical          1                  6
# 5              3068  Life Sciences          2                  8
# 11             4193  Life Sciences          2                 10
# 16             3298  Life Sciences          2                  7
# 19             3944  Life Sciences          3                  6
# ...             ...            ...        ...                ...
# 1442           4787        Medical          4                  4
# ...
