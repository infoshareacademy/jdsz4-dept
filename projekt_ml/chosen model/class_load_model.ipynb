# %%
from joblib import load
import numpy as np
import xgboost


class Using_model:
    # load best model
    def get_model():
        model = load('best_model.joblib')
        return model
    # input_values
    
    
    def input_values(x):
        
        data_array = []
        
        # age
        while True:
            try:
                age = int(input('Enter your age: '))
                
                if 1 <= age <= 120:
                    data_array.append(age)
                    break
            except:
                
                print('Enter age as a number!: ')
        
        # bmi        
        while True:
            try:
                bmi = float(input('Enter your bmi: '))
                if 10 <= bmi <= 40:
                    data_array.append(bmi)
                    break
            except:
                print('Enter bmi as a number')
        
        # children
        while True:
            try:
                chld = int(input('How many children do you have ?: '))
                if 0 <= chld <= 30:
                    data_array.append(chld)
                    break
            except:
                print('Enter children amount as a number!')
                
        # are you a smoker?

        while True:

            smk = input('Are you a smoker (y/n): ')
            if smk in ['y', 'Y']:    
                data_array.append(1)
                break
            elif smk in ['n', 'N']:
                data_array.append(0)
                break
                
        # sex
        
        while True:
            sex = input('Your sex is male/female (m/f): ')
            
            if sex in ['m', 'M']:
                data_array.append(1)
                break
            elif sex in ['f', 'F']:
                data_array.append(0)
                break
                
        # region - NE, NW, SE, SW

        while True:

            print('Select your region.')
            print('1. north-east')
            print('2. north-west')
            print('3. south-east')
            print('4. south-west')

            reg = input('Your choice: ')

            if reg in '1, 2, 3, 4':

                if reg == '1':
                    data_array.append(1)
                    data_array.append(0)
                    data_array.append(0)
                    data_array.append(0)
                    break
                elif reg == '2':
                    data_array.append(0)
                    data_array.append(1)
                    data_array.append(0)
                    data_array.append(0)
                    break
                elif reg == '3':
                    data_array.append(0)
                    data_array.append(0)
                    data_array.append(1)
                    data_array.append(0)
                    break
                elif reg == '4':
                    data_array.append(0)
                    data_array.append(0)
                    data_array.append(0)
                    data_array.append(1)
                    break
                    
        complete_output = np.array(data_array)
        complete_output = complete_output.reshape(1,-1)
        predict_value = x.predict(complete_output)
        print ('Estimated cost of insurance: ', round(predict_value), '$')

# %%
# Appka
model = Using_model.get_model()
Using_model.input_values(model)
# Out:
# Enter your age: 18
# Enter your bmi: 23
# How many children do you have ?: 0
# Are you a smoker (y/n): n
# Your sex is male/female (m/f): m
# Select your region.
# 1. north-east
# 2. north-west
# 3. south-east
# 4. south-west
# Your choice: 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-63d562b831d1> in <module>
#       1 # Appka
#       2 model = Using_model.get_model()
# ----> 3 Using_model.input_values(model)
#
# <ipython-input-1-38786a244d8c> in input_values(x)
#     113         complete_output = np.array(data_array)
#     114         complete_output = complete_output.reshape(1,-1)
# --> 115         predict_value = x.predict(complete_output)
#     116         print ('Estimated cost of insurance: ', round(predict_value), '$')
#
# ~/miniconda3/envs/nowe_srodowisko_condy/lib/python3.7/site-packages/xgboost/sklearn.py in predict(self, data, output_margin, ntree_limit, validate_features)
#     454                                           output_margin=output_margin,
#     455                                           ntree_limit=ntree_limit,
# --> 456                                           validate_features=validate_features)
#     457
#     458     def apply(self, X, ntree_limit=0):
#
# ~/miniconda3/envs/nowe_srodowisko_condy/lib/python3.7/site-packages/xgboost/core.py in predict(self, data, output_margin, ntree_limit, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features)
#    1282
#    1283         if validate_features:
# -> 1284             self._validate_features(data)
#    1285
#    1286         length = c_bst_ulong()
#
# ~/miniconda3/envs/nowe_srodowisko_condy/lib/python3.7/site-packages/xgboost/core.py in _validate_features(self, data)
#    1688
#    1689                 raise ValueError(msg.format(self.feature_names,
# -> 1690                                             data.feature_names))
#    1691
#    1692     def get_split_value_histogram(self, feature, fmap='', bins=None, as_pandas=True):
#
# ValueError: feature_names mismatch: ['age', 'bmi', 'children', 'sex_male', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8']
# expected age, region_southeast, region_northwest, bmi, region_southwest, region_northeast, sex_male, smoker_yes, children in input data
# training data did not have the following fields: f8, f1, f7, f2, f4, f6, f3, f0, f5
