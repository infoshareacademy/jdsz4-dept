# %% [markdown]
# # Projekt DL

# %%
# %matplotlib inline

from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import to_categorical

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
import cv2

# %%
# wczytanie zdjęcia
img = cv2.imread("/Users/ela/Data Scientist - InfoshareAcademy/DL/fruit-recognition/Apple/Apple A/Apple 1.png")

# %%
# Display the resulting frame
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(20,20))
# plt.gray()
plt.matshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-42ab9c5474dc> in <module>
#       1 # Display the resulting frame
# ----> 2 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       3 plt.figure(figsize=(20,20))
#       4 # plt.gray()
#       5 plt.matshow(img)
#
# error: OpenCV(3.4.2) /tmp/build/80754af9/opencv-suite_1535558553474/work/modules/imgproc/src/color.hpp:253: error: (-215:Assertion failed) VScn::contains(scn) && VDcn::contains(dcn) && VDepth::contains(depth) in function 'CvtHelper'

# %%
import glob

# %%
apple_a = glob.glob('/Users/ela/Data Scientist - InfoshareAcademy/DL/fruit-recognition/Apple/Apple A/*.png')

# %%
apple_e = glob.glob('/Users/ela/Data Scientist - InfoshareAcademy/DL/fruit-recognition/Apple/Apple E/*.png')

# %%
apples = apple_a + apple_e

# %%
n_apples = len(apples)

# %%
n_apples
# Out:
# 1356

# %%
img_height, img_width = 150, 150

# %%
apples_array = np.empty((n_apples, img_height, img_width, 3))
apples_list = []

# %%
for i, path in enumerate(apples):
    image = cv2.imread(path)
    if image.shape[:-1] != (img_height, img_width):
        image = cv2.resize(image, (img_width, img_height))
    
    apples_array[i] = image

# %%
for i, path in enumerate(apples):
    image = cv2.imread(path)
    if image.shape[:-1] != (img_height, img_width):
        image = cv2.resize(image, (img_width, img_height))
    apples_list.append(image)

# %%
apples_array_bis = np.stack(apples_list)

# %%
apples_array_bis.shape
# Out:
# (1356, 150, 150, 3)

# %%
img = cv2.cvtColor(apples_array_bis[1000], cv2.COLOR_BGR2RGB)
plt.matshow(img)
plt.show()

# %% [markdown]
# ### kod od Piotrka Januszewskiego

# %%
applesPaths = [apple_a, apple_e]

# %%
x = np.zeros(<wszystkie zdjęcia>, <wys>, <szer>, <kanały>)
y = np.zeros(<wszystkie zdjecia>,)

# %%
idx = 0
for i in range(len(applesPaths)):
    appleClass = i
    for path in applesPaths[i]:
        # wczytywanie
        x[idx] = <wczytane zdjecie>
        y[idx] = appleClass
        idx += 1
